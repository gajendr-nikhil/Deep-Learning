# %% [markdown]
# # Project: Sentiment Classification (Movie Reviews)

# %% [markdown]
# ## Curate dataset

# %%
g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# ## Pre-process data and find co-relation between data and labels

# %%
from collections import Counter
import numpy as np

# %%
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %%
# list all the words in the POSITIVE and NEGATIVE review

for i in range(len(reviews)):
    if(labels[i] == 'POSITIVE'):
        for word in reviews[i].split(" "):
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in reviews[i].split(" "):
            negative_counts[word] += 1
            total_counts[word] += 1

# %%
# Find co-relation between positive and negative words with their respective lables

pos_neg_ratios = Counter()

for term,cnt in list(total_counts.most_common()):
    if(cnt > 50):
        pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
        pos_neg_ratios[term] = pos_neg_ratio

for word,ratio in pos_neg_ratios.most_common():
    if(ratio > 1):
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log((1 / (ratio+0.01)))

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 4.6913478822291435),
#  ('antwone', 4.4773368144782069),
#  ('din', 4.4067192472642533),
#  ('gunga', 4.1896547420264252),
#  ('goldsworthy', 4.1743872698956368),
#  ('gypo', 4.0943445622221004),
#  ('yokai', 4.0943445622221004),
#  ('paulie', 4.0775374439057197),
#  ('visconti', 3.9318256327243257),
#  ('flavia', 3.9318256327243257),
#  ('gundam', 3.4231762883809305),
#  ('iturbi', 3.2771447329921766),
#  ('felix', 3.1527360223636558),
#  ('capote', 3.0122615755052013),
#  ('fido', 3.0081547935525483),
#  ('excellently', 2.9789251552376097),
#  ('vance', 2.9444389791664403),
#  ('kolchak', 2.9311937524164198),
#  ('deanna', 2.9267394020670396),
#  ('hayworth', 2.9267394020670396),
#  ('sammo', 2.8526314299133175),
#  ('biko', 2.8332133440562162),
#  ('sox', 2.8332133440562162),
#  ('laputa', 2.8332133440562162),
#  ('polanski', 2.8233610476132043),
#  ('alvin', 2.8183982582710754),
#  ('matthau', 2.8067217286092401),
#  ('mathieu', 2.7725887222397811),
#  ('gilliam', 2.7245795030534206),
#  ('victoria', 2.6810215287142909),
#  ('chavez', 2.6672282065819548),
#  ('ratso', 2.653241964607215),
#  ('harriet', 2.6390573296152584),
#  ('mildred', 2.6026896854443837),
#  ('ultimatum', 2.6026896854443837),
#  ('mclaglen', 2.5649493574615367),
#  ('corbett', 2.5494451709255714),
#  ('gandhi', 2.5389738710582761),
#  ('delightfully', 2.5257286443082556),
#  ('sirk', 2.5199979695992702),
#  ('creasy', 2.5055259369907361),
#  ('braveheart', 2.5014359517392109),
#  ('kazan', 2.4849066497880004),
#  ('mccoy', 2.456735772821304),
#  ('flawless', 2.451005098112319),
#  ('othello', 2.4485390056171252),
#  ('novak', 2.4361164856185682),
#  ('christy', 2.4203681286504293),
#  ('cheadle', 2.4159137783010487),
#  ('fuller', 2.3978952727983707),
#  ('ramones', 2.3978952727983707),
#  ('cal', 2.3608540011180215),
#  ('winchester', 2.3353749158170367),
#  ('chamberlain', 2.3191143949452564),
#  ('rea', 2.3025850929940459),
#  ('haines', 2.3025850929940459),
#  ('colman', 2.3025850929940459),
#  ('carla', 2.2772672850097559),
#  ('sabrina', 2.2643638801738479),
#  ('superbly', 2.2600254785752498),
#  ('peters', 2.2512917986064953),
#  ('northam', 2.2407096892759584),
#  ('tenant', 2.2284771208403238),
#  ('kinnear', 2.2155737160044158),
#  ('raines', 2.1972245773362196),
#  ('georges', 2.1649637151179979),
#  ('perfection', 2.1594842493533721),
#  ('rukh', 2.1594842493533721),
#  ('astaire', 2.1400661634962708),
#  ('dixon', 2.1400661634962708),
#  ('trier', 2.1316272948504063),
#  ('miyazaki', 2.120263536200091),
#  ('malone', 2.0794415416798357),
#  ('mol', 2.0476928433652555),
#  ('captures', 2.0386195471595809),
#  ('edith', 2.0368819272610401),
#  ('scoop', 2.0314323224934752),
#  ('pickford', 2.0314323224934752),
#  ('voight', 2.0301704926730531),
#  ('wonderfully', 2.0218960560332353),
#  ('zorro', 2.0053335695261141),
#  ('dandy', 1.9980959022258835),
#  ('heartbreaking', 1.9924301646902061),
#  ('powell', 1.9783454248084671),
#  ('wang', 1.9740810260220096),
#  ('brosnan', 1.9547990964725592),
#  ('masterful', 1.9459101490553132),
#  ('hawke', 1.9459101490553132),
#  ('truman', 1.9459101490553132),
#  ('sg', 1.927891643552635),
#  ('masterson', 1.927891643552635),
#  ('sunrise', 1.9252908618525775),
#  ('lily', 1.9203768470501485),
#  ('expertly', 1.9095425048844386),
#  ('bakshi', 1.9029851043382795),
#  ('lincoln', 1.9014583864844796),
#  ('europa', 1.8971199848858813),
#  ('darren', 1.8925641683500207),
#  ('tomei', 1.8827312474337816),
#  ('cypher', 1.8718021769015913),
#  ('greene', 1.8607523407150064),
#  ('carell', 1.8588987720656835),
#  ('refreshing', 1.8551812956655511),
#  ('montana', 1.8538912503350613),
#  ('pegg', 1.8523840910444898),
#  ('breathtaking', 1.8481124057791867),
#  ('bourne', 1.8478489358790986),
#  ('lemmon', 1.8458266904983307),
#  ('walsh', 1.8325814637483102),
#  ('explores', 1.8082887711792655),
#  ('steele', 1.8082887711792655),
#  ('delightful', 1.8002701588959635),
#  ('flynn', 1.7996646487351682),
#  ('chess', 1.7797832781813394),
#  ('andrews', 1.7764919970972666),
#  ('homer', 1.7692866133759964),
#  ('beautifully', 1.7626953362841438),
#  ('soccer', 1.7578579175523736),
#  ('ira', 1.7491998548092591),
#  ('deliciously', 1.7491998548092591),
#  ('lumet', 1.7462970951512977),
#  ('affection', 1.7452394535931621),
#  ('elvira', 1.7397031072720019),
#  ('kidman', 1.729239112246721),
#  ('underrated', 1.7197859696029656),
#  ('sopranos', 1.7197859696029656),
#  ('gripping', 1.7165360479904674),
#  ('superb', 1.7091514458966952),
#  ('nina', 1.7047480922384253),
#  ('paula', 1.6863989535702288),
#  ('deliverance', 1.6863989535702288),
#  ('tierney', 1.6739764335716716),
#  ('delight', 1.6714733033535532),
#  ('welles', 1.6677068205580761),
#  ('reeve', 1.6677068205580761),
#  ('sadness', 1.663505133704376),
#  ('technicolor', 1.65455834771457),
#  ('ae', 1.6529230243738393),
#  ('soylent', 1.6486586255873816),
#  ('kline', 1.6422277352570913),
#  ('sinatra', 1.6389967146756448),
#  ('touching', 1.637217476541176),
#  ('gershwin', 1.6314168191528755),
#  ('timeless', 1.62924053973028),
#  ('macy', 1.6211339521972916),
#  ('unforgettable', 1.6177367152487956),
#  ('favorites', 1.6158688027643908),
#  ('stewart', 1.6119987332957739),
#  ('sullivan', 1.6094379124341003),
#  ('extraordinary', 1.6094379124341003),
#  ('hartley', 1.6094379124341003),
#  ('grayson', 1.6094379124341003),
#  ('kurosawa', 1.6094379124341003),
#  ('brilliantly', 1.5950491749820008),
#  ('clara', 1.5910887737659039),
#  ('liu', 1.5910887737659039),
#  ('einstein', 1.5910887737659039),
#  ('dustin', 1.589235205116581),
#  ('iran', 1.5841201044498106),
#  ('shanghai', 1.5804503755608481),
#  ('mesmerizing', 1.5723966407537513),
#  ('friendship', 1.5677652160335325),
#  ('wonderful', 1.5645425925262093),
#  ('heartwarming', 1.5581446180465499),
#  ('palma', 1.5553706911638245),
#  ('watson', 1.5546296759391054),
#  ('wrenching', 1.5533484457830569),
#  ('fairbanks', 1.547562508716013),
#  ('magnificent', 1.54663701119507),
#  ('finest', 1.5462590108125689),
#  ('understated', 1.5448993912965292),
#  ('jackie', 1.5439233053234738),
#  ('ritter', 1.5404450409471491),
#  ('simmons', 1.5404450409471491),
#  ('election', 1.5404450409471491),
#  ('lang', 1.5260563034950492),
#  ('rowlands', 1.5260563034950492),
#  ('tremendous', 1.5184661342283736),
#  ('conveys', 1.5125880864441827),
#  ('nathan', 1.5114575040738967),
#  ('buffalo', 1.5114575040738967),
#  ('scrooge', 1.5105920777974677),
#  ('freedom', 1.5091151908062312),
#  ('fantastic', 1.5048433868558566),
#  ('elliott', 1.5040773967762742),
#  ('terrific', 1.5026699370083942),
#  ('spock', 1.4975199962301151),
#  ('noir', 1.493925025312256),
#  ('sidney', 1.493925025312256),
#  ('loy', 1.493925025312256),
#  ('outstanding', 1.4910053152089213),
#  ('pleasantly', 1.4894785973551214),
#  ('mann', 1.4894785973551214),
#  ('nancy', 1.488077055429833),
#  ('heartfelt', 1.488077055429833),
#  ('marie', 1.4825711915553104),
#  ('hyde', 1.479076094570857),
#  ('marvelous', 1.4739999415389962),
#  ('odyssey', 1.4733057381095203),
#  ('astonishing', 1.466337068793427),
#  ('andre', 1.466337068793427),
#  ('stack', 1.466337068793427),
#  ('excellent', 1.4647538505723599),
#  ('delicate', 1.4604023332736125),
#  ('ruth', 1.4596256342054401),
#  ('sondra', 1.4586150226995167),
#  ('kitty', 1.455287232606842),
#  ('sidewalk', 1.452252328911688),
#  ('absorbing', 1.452252328911688),
#  ('longing', 1.452252328911688),
#  ('cunningham', 1.452252328911688),
#  ('stargate', 1.4469189829363254),
#  ('jedi', 1.4469189829363254),
#  ('stanwyck', 1.4412101187160054),
#  ('sassy', 1.4384801142904609),
#  ('fontaine', 1.4384801142904609),
#  ('macarthur', 1.4375876555074412),
#  ('widmark', 1.4350845252893227),
#  ('soprano', 1.4350845252893227),
#  ('jose', 1.4350845252893227),
#  ('hadley', 1.4307461236907244),
#  ('splendid', 1.4271163556401458),
#  ('detract', 1.4271163556401458),
#  ('layers', 1.4240346891027378),
#  ('chan', 1.423108334242607),
#  ('exceptional', 1.4201959127955721),
#  ('stark', 1.4190841839428816),
#  ('tender', 1.410986973710262),
#  ('demille', 1.4087672169719492),
#  ('jacques', 1.4087672169719492),
#  ('gielgud', 1.4087672169719492),
#  ('gentle', 1.4078005663408544),
#  ('definitive', 1.4069136483226263),
#  ('denis', 1.4039939382192914),
#  ('poignant', 1.4022947024663317),
#  ('ruby', 1.3993664426872434),
#  ('gem', 1.3932148039644643),
#  ('amazing', 1.3919815802404802),
#  ('chilling', 1.3862943611198906),
#  ('fisher', 1.3862943611198906),
#  ('davies', 1.3862943611198906),
#  ('captivating', 1.3862943611198906),
#  ('dickens', 1.3862943611198906),
#  ('elegant', 1.3730491343698699),
#  ('sentinel', 1.3705460041517514),
#  ('cerebral', 1.366876275262789),
#  ('restrained', 1.366876275262789),
#  ('darker', 1.3652409519220583),
#  ('pathos', 1.3633048428951919),
#  ('gerard', 1.3596261140377293),
#  ('april', 1.3499267169490159),
#  ('pixar', 1.3499267169490159),
#  ('kelly', 1.3461743673304654),
#  ('rewarding', 1.3437347467010947),
#  ('blake', 1.3418425985490567),
#  ('uplifting', 1.3411739258394211),
#  ('neglected', 1.3397743454849977),
#  ('overlooked', 1.329135947279942),
#  ('ralph', 1.32818673031261),
#  ('standout', 1.3268709406490899),
#  ('stunningly', 1.3268709406490899),
#  ('amrita', 1.3268709406490899),
#  ('juliette', 1.3217558399823195),
#  ('vanilla', 1.3217558399823195),
#  ('cushing', 1.3173014896329391),
#  ('bette', 1.3156767939059373),
#  ('fleet', 1.3156767939059373),
#  ('hoffman', 1.3150668518315229),
#  ('gentleman', 1.3143208614948014),
#  ('cole', 1.3121863889661687),
#  ('marc', 1.3099213823353166),
#  ('delicious', 1.3062516534463542),
#  ('shines', 1.3049487216659381),
#  ('powerful', 1.2999662776313934),
#  ('dalton', 1.2992829841302609),
#  ('swim', 1.2992829841302609),
#  ('bud', 1.2992829841302609),
#  ('thelma', 1.2992829841302609),
#  ('notch', 1.2950456896547455),
#  ('richardson', 1.2947271675944001),
#  ('errol', 1.2927683031090671),
#  ('engrossing', 1.2927683031090671),
#  ('remarkable', 1.2883688239495823),
#  ('preminger', 1.2878542883066382),
#  ('pitt', 1.286210902562908),
#  ('winters', 1.2833463918674481),
#  ('neill', 1.2809338454620642),
#  ('vivid', 1.2762934659055623),
#  ('gritty', 1.2757524867200667),
#  ('giallo', 1.2745029551317739),
#  ('portrait', 1.2704625455947689),
#  ('innocence', 1.2694300209805796),
#  ('psychiatrist', 1.2685113254635072),
#  ('favorite', 1.2668956297860055),
#  ('ensemble', 1.2656663733312759),
#  ('riveting', 1.2656663733312759),
#  ('stunning', 1.2622417124499117),
#  ('loneliness', 1.2611312181658845),
#  ('orleans', 1.2602536402245255),
#  ('burns', 1.259880436264232),
#  ('cleverly', 1.2595426554807467),
#  ('garbo', 1.258954938743289),
#  ('barbara', 1.2580400255962119),
#  ('philip', 1.2527629684953681),
#  ('panic', 1.2527629684953681),
#  ('holly', 1.2527629684953681),
#  ('scariest', 1.2527629684953681),
#  ('sailor', 1.2527629684953681),
#  ('pfeiffer', 1.2527629684953681),
#  ('carol', 1.2481440226390734),
#  ('perfect', 1.246742480713785),
#  ('appreciated', 1.2462482874741743),
#  ('september', 1.2459370034249682),
#  ('divine', 1.2417131323087831),
#  ('frontier', 1.2417131323087831),
#  ('favourite', 1.2411123512753928),
#  ('journey', 1.2367626271489269),
#  ('rural', 1.235471471385307),
#  ('bond', 1.2321436812926323),
#  ('strengths', 1.2321436812926323),
#  ('builds', 1.2305398317106577),
#  ('brilliant', 1.2287554137664785),
#  ('brooklyn', 1.2286654169163074),
#  ('paxton', 1.2272296664902032),
#  ('von', 1.225175011976539),
#  ('alison', 1.2237754316221157),
#  ('alexandre', 1.2237754316221157),
#  ('recommended', 1.2163953243244932),
#  ('unfolds', 1.2163953243244932),
#  ('sissy', 1.2144441041932312),
#  ('pierce', 1.2144441041932312),
#  ('rookie', 1.2110902720948),
#  ('energetic', 1.2110902720948),
#  ('vividly', 1.2110902720948),
#  ('accessible', 1.2110902720948),
#  ('bacall', 1.2039728043259361),
#  ('rifle', 1.2039728043259361),
#  ('neatly', 1.2039728043259361),
#  ('daniel', 1.20215296760895),
#  ('coup', 1.1977031913123406),
#  ('perfectly', 1.1971931173405572),
#  ('crafted', 1.1962507582320256),
#  ('cultures', 1.1962507582320256),
#  ('lavish', 1.1962507582320256),
#  ('vega', 1.1962507582320256),
#  ('prince', 1.1939224684724346),
#  ('troubled', 1.192138346678933),
#  ('devastating', 1.1895840668738364),
#  ('posey', 1.1871656860095547),
#  ('consequences', 1.1865810616140668),
#  ('bsg', 1.1837700970084166),
#  ('rita', 1.1826954058786512),
#  ('haunting', 1.1814999484738773),
#  ('cinderella', 1.180052620608284),
#  ('anton', 1.1786549963416462),
#  ('alexander', 1.1759989522835299),
#  ('emotions', 1.1753049094563641),
#  ('viewings', 1.1749852674526837),
#  ('reflects', 1.1741198411762548),
#  ('boxing', 1.1735135968412274),
#  ('subtle', 1.1734135017508081),
#  ('phenomenal', 1.1727202608218317),
#  ('cuban', 1.1727202608218317),
#  ('reign', 1.1700712526502546),
#  ('kyle', 1.1685708772750201),
#  ('sublime', 1.1676051601550612),
#  ('berkeley', 1.1676051601550612),
#  ('solo', 1.1657515915057384),
#  ('curtis', 1.1649873576129823),
#  ('championship', 1.1631508098056809),
#  ('ustinov', 1.1631508098056809),
#  ('masterfully', 1.1631508098056809),
#  ('bravo', 1.1631508098056809),
#  ('rare', 1.1566438362402944),
#  ('loved', 1.1563661500586044),
#  ('daughters', 1.1526795099383853),
#  ('ladder', 1.1526795099383853),
#  ('karl', 1.1499055830556602),
#  ('beckinsale', 1.148622709242771),
#  ('marion', 1.1451323043030026),
#  ('courage', 1.1438688802562305),
#  ('depicts', 1.1430640512389434),
#  ('dentist', 1.1426722784621401),
#  ('highly', 1.1420208631618658),
#  ('nominated', 1.1409146683587992),
#  ('tony', 1.1397491942285991),
#  ('clan', 1.1370785694959058),
#  ('paramount', 1.133098464739279),
#  ('draws', 1.1325138403437911),
#  ('everyday', 1.1306150197542835),
#  ('contrast', 1.1284652518177909),
#  ('lends', 1.1239300966523995),
#  ('aftermath', 1.1239300966523995),
#  ('unusually', 1.1239300966523995),
#  ('cried', 1.1213405397456659),
#  ('fabulous', 1.1210851445201684),
#  ('ned', 1.120591195386885),
#  ('fay', 1.120591195386885),
#  ('mice', 1.120591195386885),
#  ('exquisite', 1.1192315758708453),
#  ('emma', 1.1184149159642893),
#  ('loretta', 1.1180303745252111),
#  ('globe', 1.1180303745252111),
#  ('vibrant', 1.1180303745252111),
#  ('loyalty', 1.1151415906193203),
#  ('damon', 1.1136501660326501),
#  ('sensitive', 1.113318436057805),
#  ('orson', 1.1124056108004454),
#  ('corruption', 1.1118575154181303),
#  ('smooth', 1.1089750757036563),
#  ('dramas', 1.1080910326226534),
#  ('today', 1.1050431789984001),
#  ('helps', 1.1023091505494358),
#  ('inspiring', 1.0986122886681098),
#  ('shelley', 1.0986122886681098),
#  ('simplicity', 1.0986122886681098),
#  ('newman', 1.0986122886681098),
#  ('realities', 1.0986122886681098),
#  ('irene', 1.0986122886681098),
#  ('lola', 1.0986122886681098),
#  ('caron', 1.0986122886681098),
#  ('herbert', 1.0986122886681098),
#  ('manners', 1.0986122886681098),
#  ('jimmy', 1.0937696641923216),
#  ('awesome', 1.0931328229034842),
#  ('unique', 1.0881409888008142),
#  ('tragic', 1.0871835928444868),
#  ('intense', 1.0870514662670339),
#  ('stellar', 1.0857088838322018),
#  ('thoughtful', 1.085189268335969),
#  ('june', 1.0840134892469568),
#  ('warmth', 1.0833448165373212),
#  ('tends', 1.0833448165373212),
#  ('deniro', 1.0826119473216687),
#  ('rival', 1.0822184788924332),
#  ('wwe', 1.0818051703517284),
#  ('beatles', 1.0809127115687087),
#  ('vader', 1.0809127115687087),
#  ('provides', 1.0797081340289569),
#  ('depression', 1.0782034170369026),
#  ('shy', 1.0775588794702773),
#  ('dazzling', 1.0775588794702773),
#  ('contribution', 1.0775588794702773),
#  ('carrie', 1.076139432816051),
#  ('isolation', 1.076139432816051),
#  ('packs', 1.076139432816051),
#  ('blend', 1.0753554265038423),
#  ('arkin', 1.0745147370890491),
#  ('owl', 1.0745147370890491),
#  ('hank', 1.0736109864626924),
#  ('diana', 1.0726368022648489),
#  ('adorable', 1.0726368022648489),
#  ('unexpected', 1.0722255334949147),
#  ('affect', 1.0704414117014134),
#  ('intimate', 1.0691984034618165),
#  ('poem', 1.0678406300013561),
#  ('achievement', 1.0668635903535293),
#  ('bettie', 1.0663514264498881),
#  ('happiness', 1.0632729222228008),
#  ('renaissance', 1.0628942060660305),
#  ('glorious', 1.0608719606852626),
#  ('prominent', 1.0608719606852626),
#  ('rounded', 1.0608719606852626),
#  ('mitch', 1.0586069540544105),
#  ('fishburne', 1.0586069540544105),
#  ('dub', 1.0577902941478545),
#  ('macabre', 1.0560526742493137),
#  ('davis', 1.0541605260972757),
#  ('vintage', 1.0531499145913523),
#  ('terrifying', 1.0525211814678428),
#  ('beauty', 1.050410186850232),
#  ('psyche', 1.0498221244986776),
#  ('ideal', 1.0479685558493548),
#  ('esther', 1.0473189942805592),
#  ('fears', 1.0467872208035236),
#  ('lena', 1.0459685551826878),
#  ('wilder', 1.0445450673978338),
#  ('hong', 1.0438040521731147),
#  ('seasons', 1.0433496099930604),
#  ('fascinating', 1.0414538748281612),
#  ('carries', 1.0345904299031787),
#  ('enhanced', 1.0340737675305385),
#  ('palance', 1.0330150061822965),
#  ('sandra', 1.032362903126909),
#  ('satisfying', 1.0321225473992768),
#  ('definite', 1.0319209141694374),
#  ('touched', 1.0296194171811581),
#  ('laurence', 1.0296194171811581),
#  ('collette', 1.0296194171811581),
#  ('cliffhanger', 1.0296194171811581),
#  ('fassbinder', 1.0296194171811581),
#  ('restored', 1.0266387890430204),
#  ('oldest', 1.0258529343856813),
#  ('muppets', 1.0258529343856813),
#  ('greatest', 1.0248947127715422),
#  ('wider', 1.0245043165143877),
#  ('creates', 1.0241097613701886),
#  ('aunt', 1.023388867430522),
#  ('waitress', 1.023388867430522),
#  ('der', 1.023388867430522),
#  ('walter', 1.022328983918479),
#  ('spectacular', 1.0198314108149955),
#  ('portrayal', 1.0189810189761024),
#  ('startling', 1.0169342576538425),
#  ('gable', 1.0169342576538425),
#  ('bloom', 1.0169342576538425),
#  ('subtly', 1.0169342576538425),
#  ('difficulties', 1.0159205728229963),
#  ('kansas', 1.0159205728229963),
#  ('robinson', 1.0152306797290584),
#  ('bands', 1.0152306797290584),
#  ('ann', 1.0127808528183286),
#  ('enterprise', 1.0116009116784799),
#  ('musicals', 1.0096648026516135),
#  ('deeply', 1.0094845087721023),
#  ('rhythm', 1.0068047394149868),
#  ('incredible', 1.0061677561461084),
#  ('mature', 1.0060195018402847),
#  ('authorities', 1.0014485402144619),
#  ('thrilled', 1.0014485402144619),
#  ('boyer', 1.0014485402144619),
#  ('goodman', 0.99852883011112725),
#  ('artistry', 0.99852883011112725),
#  ('triumph', 0.99682959435816731),
#  ('margaret', 0.99682959435816731),
#  ('nominations', 0.99542805243287902),
#  ('navy', 0.99493385919326827),
#  ('passionate', 0.99462257514406205),
#  ('gillian', 0.99325177301028345),
#  ('harry', 0.99176919305006062),
#  ('lucas', 0.990398704027877),
#  ('sweet', 0.98966110487955483),
#  ('fragile', 0.98861139345378124),
#  ('nightclub', 0.98861139345378124),
#  ('miranda', 0.98861139345378124),
#  ('joey', 0.98794672078059009),
#  ('comparisons', 0.98738665355788524),
#  ('oscar', 0.98721905111049713),
#  ('balance', 0.98649499054740353),
#  ('vulnerable', 0.98581679452276538),
#  ('warm', 0.98485340331145166),
#  ('ages', 0.98449898190068863),
#  ('guilt', 0.98082925301172619),
#  ('glover', 0.98082925301172619),
#  ('carrey', 0.98082925301172619),
#  ('diverse', 0.98082925301172619),
#  ('sang', 0.98082925301172619),
#  ('learns', 0.97881108885548895),
#  ('unusual', 0.97788374278196932),
#  ('sons', 0.97777581552483595),
#  ('complex', 0.97761897738147796),
#  ('essence', 0.97753435711487369),
#  ('brazil', 0.9769153536905899),
#  ('widow', 0.97650959186720987),
#  ('vengeance', 0.97600996657577732),
#  ('solid', 0.97537964824416146),
#  ('eugene', 0.97537964824416146),
#  ('galaxy', 0.97344914571410368),
#  ('limitations', 0.97344914571410368),
#  ('wonderland', 0.97344914571410368),
#  ('beautiful', 0.97326301262841053),
#  ('holmes', 0.97246100334120955),
#  ('awe', 0.97186058302896583),
#  ('vhs', 0.97116734209998934),
#  ('eerie', 0.97116734209998934),
#  ('recognition', 0.97077891715822484),
#  ('lonely', 0.96873720724669754),
#  ('grim', 0.96873720724669754),
#  ('sport', 0.96825047080486615),
#  ('ingenious', 0.9675840262617057),
#  ('cher', 0.9675840262617057),
#  ('inventive', 0.96684301103698644),
#  ('debut', 0.96508089604358704),
#  ('seymour', 0.96508089604358704),
#  ('pierre', 0.96508089604358704),
#  ('destiny', 0.96343751029985703),
#  ('thrillers', 0.96281074750904794),
#  ('provocative', 0.96281074750904794),
#  ('pokemon', 0.96141116715462471),
#  ('convincingly', 0.96141116715462471),
#  ('tears', 0.95977584381389391),
#  ('eleven', 0.95977584381389391),
#  ('conrad', 0.95977584381389391),
#  ('integrity', 0.95885034629295096),
#  ('rose', 0.95664202739772253),
#  ('feelings', 0.95551144502743635),
#  ('ginger', 0.95551144502743635),
#  ('immigrant', 0.95551144502743635),
#  ('dynamics', 0.95551144502743635),
#  ('winning', 0.95471810900804055),
#  ('stanley', 0.95387344302319799),
#  ('cox', 0.95343027882361187),
#  ('paris', 0.95278479030472663),
#  ('facing', 0.9526583760450299),
#  ('poetic', 0.9526583760450299),
#  ('heart', 0.95238806924516806),
#  ('relax', 0.95200881447623431),
#  ('hooked', 0.95155887071161305),
#  ('pirate', 0.95097628986204519),
#  ('comfortable', 0.94803943018873538),
#  ('willis', 0.94659608136948403),
#  ('mgm', 0.94446160884085151),
#  ('rosemary', 0.94446160884085151),
#  ('compassion', 0.9420432279765697),
#  ('masterpiece', 0.94155039863339296),
#  ('themes', 0.94118828349588235),
#  ('ricky', 0.94098334446452658),
#  ('mistress', 0.94000725849147115),
#  ('danny', 0.93967118051821874),
#  ('judd', 0.93826963859293022),
#  ('nolte', 0.93609335917033476),
#  ('anime', 0.93378388932167222),
#  ('perry', 0.93328830824272613),
#  ('joy', 0.93301752567946861),
#  ('raymond', 0.93155820400494349),
#  ('lovable', 0.93081883243706487),
#  ('nomination', 0.93047536686611143),
#  ('mysteries', 0.92953595862417571),
#  ('hal', 0.92953595862417571),
#  ('july', 0.92953595862417571),
#  ('detroit', 0.92953595862417571),
#  ('louis', 0.92871325187271225),
#  ('laurie', 0.92798677163734633),
#  ('jules', 0.92798677163734633),
#  ('keen', 0.92676203174145044),
#  ('mirrors', 0.92676203174145044),
#  ('charming', 0.92520609553210742),
#  ('urban', 0.92367083917177761),
#  ('blunt', 0.92367083917177761),
#  ('allows', 0.92183091224977043),
#  ('impact', 0.91815814604895041),
#  ('italy', 0.91629073187415511),
#  ('gradually', 0.91629073187415511),
#  ('lifestyle', 0.91629073187415511),
#  ('leo', 0.91629073187415511),
#  ('attitudes', 0.91629073187415511),
#  ('hara', 0.91629073187415511),
#  ('spinal', 0.91629073187415511),
#  ('arranged', 0.91629073187415511),
#  ('spy', 0.91289514287301687),
#  ('treat', 0.91193342650519937),
#  ('subsequent', 0.91056005716517008),
#  ('kennedy', 0.90981821736853763),
#  ('loving', 0.90967549275543591),
#  ('surprising', 0.90937028902958128),
#  ('quiet', 0.90648673177753425),
#  ('winter', 0.90624039602065365),
#  ('reveals', 0.90490540964902977),
#  ('raw', 0.90445627422715225),
#  ('minnelli', 0.90445627422715225),
#  ('casablanca', 0.9028677115420144),
#  ('funniest', 0.90078654533818991),
#  ('pleased', 0.89994159387262562),
#  ('norman', 0.89994159387262562),
#  ('doubts', 0.89948361355777384),
#  ('unpredictable', 0.89948361355777384),
#  ('thief', 0.89874642222324552),
#  ('season', 0.89827222637147675),
#  ('secrets', 0.89794159320595857),
#  ('colorful', 0.89705936994626756),
#  ('highest', 0.8967461358011849),
#  ('guinness', 0.89608802455663572),
#  ('compelling', 0.89462923509297576),
#  ('youthful', 0.8938178760220965),
#  ('natured', 0.8938178760220965),
#  ('painter', 0.8938178760220965),
#  ('danes', 0.89248008318043659),
#  ('courtroom', 0.89097292388986515),
#  ('castle', 0.88967708335606499),
#  ('kudos', 0.88889175768604067),
#  ('great', 0.88810470901464589),
#  ('baseball', 0.88730319500090271),
#  ('subtitles', 0.88730319500090271),
#  ('bleak', 0.88730319500090271),
#  ('iconic', 0.88730319500090271),
#  ('cope', 0.88730319500090271),
#  ('winner', 0.88643776872447388),
#  ('tragedy', 0.88563699078315261),
#  ('todd', 0.88551907320740142),
#  ('lively', 0.88503818837005055),
#  ('mutual', 0.88420241732265448),
#  ('reflection', 0.88238918019847368),
#  ('moody', 0.88119941206288499),
#  ('voyage', 0.88035872264809167),
#  ('combines', 0.88035872264809167),
#  ('goods', 0.88035872264809167),
#  ('downs', 0.88035872264809167),
#  ('nicely', 0.87924946019380601),
#  ('arthur', 0.87546873735389985),
#  ('palace', 0.87546873735389985),
#  ('troubles', 0.87546873735389985),
#  ('christie', 0.87546873735389985),
#  ('essential', 0.87373111745535925),
#  ('gorgeous', 0.8731725250935497),
#  ('fonda', 0.87294029100054127),
#  ('eastwood', 0.87139541196626402),
#  ('focuses', 0.87082835779739776),
#  ('colours', 0.87082835779739776),
#  ('fatale', 0.87082835779739776),
#  ('enjoyed', 0.87070195951624607),
#  ('natural', 0.86997924506912838),
#  ('belushi', 0.86903784702360953),
#  ('intensity', 0.86835126958503595),
#  ('witty', 0.86824103423244681),
#  ('portrayals', 0.86750056770472306),
#  ('woo', 0.86499743748660451),
#  ('seldom', 0.86499743748660451),
#  ('romances', 0.86499743748660451),
#  ('nuances', 0.86499743748660451),
#  ('rob', 0.8642954367557748),
#  ('worlds', 0.86377269759070874),
#  ('walt', 0.86222351060387925),
#  ('health', 0.86113891179907498),
#  ('muppet', 0.86020126522311158),
#  ('magical', 0.85953791528170564),
#  ('deeper', 0.85802182375017932),
#  ('paranoia', 0.8574502318512216),
#  ('lucy', 0.85618680780444956),
#  ('moving', 0.85566611005772031),
#  ('establish', 0.85566611005772031),
#  ('jewel', 0.85566611005772031),
#  ('departure', 0.85441532815606758),
#  ('differently', 0.85441532815606758),
#  ('lasting', 0.85441532815606758),
#  ('celebration', 0.85348983063512474),
#  ('lovely', 0.85290640004681306),
#  ('despair', 0.85277732615182922),
#  ('purple', 0.8513711857748395),
#  ('memorable', 0.84801189112086062),
#  ('sings', 0.84729786038720367),
#  ('drake', 0.84729786038720367),
#  ('crisp', 0.84729786038720367),
#  ('craig', 0.84342938360928321),
#  ('modesty', 0.84342938360928321),
#  ('relate', 0.84326559685926517),
#  ('episodes', 0.84223712084137292),
#  ('strong', 0.84167135777060931),
#  ('nicole', 0.84156718567821853),
#  ('inspirational', 0.83975065475182076),
#  ('smith', 0.83959811108590054),
#  ('darth', 0.8383291904044432),
#  ('debra', 0.8383291904044432),
#  ('tear', 0.83704136022001441),
#  ('amazon', 0.83479769762297218),
#  ('quaid', 0.83479769762297218),
#  ('apartment', 0.83333115290549531),
#  ('princess', 0.83290912293510388),
#  ('disagree', 0.83290912293510388),
#  ('morris', 0.83290912293510388),
#  ('bates', 0.83290912293510388),
#  ('trials', 0.83290912293510388),
#  ('niece', 0.83290912293510388),
#  ('kung', 0.83173334384609199),
#  ('adventure', 0.83150561393278388),
#  ('appreciation', 0.83129751904076243),
#  ('optimistic', 0.83034830207343024),
#  ('columbo', 0.82667857318446791),
#  ('jake', 0.82667857318446791),
#  ('carey', 0.82667857318446791),
#  ('lukas', 0.82667857318446791),
#  ('adds', 0.82485652591452319),
#  ('hart', 0.82472353834866463),
#  ('strength', 0.82417544296634937),
#  ('realizes', 0.82360006895738058),
#  ('dave', 0.8232003088081431),
#  ('deliberate', 0.8232003088081431),
#  ('subway', 0.8232003088081431),
#  ('worms', 0.8232003088081431),
#  ('childhood', 0.82208086393583857),
#  ('weaknesses', 0.82098055206983034),
#  ('acceptance', 0.82098055206983034),
#  ('marvel', 0.82098055206983034),
#  ('forbidden', 0.81989888619908913),
#  ('icon', 0.81944090588423735),
#  ('tight', 0.81883539572344199),
#  ('surreal', 0.8178506590609026),
#  ('manager', 0.81770990320170756),
#  ('christina', 0.8167611365271219),
#  ('spine', 0.8167611365271219),
#  ('dancer', 0.81574950265227764),
#  ('arrival', 0.81503699816898212),
#  ('smiling', 0.81503699816898212),
#  ('widely', 0.81503699816898212),
#  ('studios', 0.81093021621632877),
#  ('con', 0.81093021621632877),
#  ('obtain', 0.81093021621632877),
#  ('informative', 0.81093021621632877),
#  ('miike', 0.80821651034473263),
#  ('realistic', 0.80807714723392232),
#  ('explicit', 0.80792269515237358),
#  ('kurt', 0.8060875917405409),
#  ('towers', 0.80562516398663564),
#  ('traditional', 0.80535917116687328),
#  ('deals', 0.80535917116687328),
#  ('holds', 0.80493858654806194),
#  ('carl', 0.80437281567016972),
#  ('achieves', 0.80437281567016972),
#  ('duel', 0.80437281567016972),
#  ('whites', 0.80437281567016972),
#  ('gibson', 0.80437281567016972),
#  ('touches', 0.80396154690023547),
#  ('gene', 0.80314807577427383),
#  ('albert', 0.8027669055771679),
#  ('abc', 0.80234647252493729),
#  ('businessman', 0.80234647252493729),
#  ('widescreen', 0.80077784475231062),
#  ('confident', 0.80077784475231062),
#  ('understands', 0.80077784475231062),
#  ('cry', 0.80011930011211307),
#  ('sides', 0.7995275841185171),
#  ('develops', 0.79850769621777162),
#  ('eyre', 0.79850769621777162),
#  ('embrace', 0.79850769621777162),
#  ('jealousy', 0.79850769621777162),
#  ('melvyn', 0.79850769621777162),
#  ('crippled', 0.79850769621777162),
#  ('dances', 0.79694397424158891),
#  ('oscars', 0.79633141679517616),
#  ('martha', 0.79633141679517616),
#  ('challenges', 0.79633141679517616),
#  ('brendan', 0.79633141679517616),
#  ('legendary', 0.79600456599965308),
#  ('hearted', 0.79492987486988764),
#  ('importance', 0.79492987486988764),
#  ('portraying', 0.79356592830699269),
#  ('residents', 0.79323063911692793),
#  ('impressed', 0.79258107754813223),
#  ('straightforward', 0.79223808320417632),
#  ('servant', 0.79223808320417632),
#  ('teaches', 0.79223808320417632),
#  ('waters', 0.79112758892014912),
#  ('empire', 0.79078565012386137),
#  ('edge', 0.789774016249017),
#  ('jean', 0.78845736036427028),
#  ('environment', 0.78845736036427028),
#  ('miniseries', 0.78845736036427028),
#  ('carmen', 0.78845736036427028),
#  ('approaches', 0.78845736036427028),
#  ('sentimental', 0.7864791203521645),
#  ('captured', 0.78623760362595729),
#  ('styles', 0.78592891401091158),
#  ('daring', 0.78592891401091158),
#  ('disappoint', 0.78552050069096035),
#  ('antonioni', 0.78495472981306824),
#  ('feat', 0.78411895876567206),
#  ('dudley', 0.78411895876567206),
#  ('wax', 0.78411895876567206),
#  ('frank', 0.78275933924963248),
#  ('tense', 0.78275933924963248),
#  ('backgrounds', 0.78275933924963248),
#  ('matches', 0.78275933924963248),
#  ('gothic', 0.78209466657644144),
#  ('sharp', 0.7814397877056235),
#  ('achieved', 0.78015855754957497),
#  ('paintings', 0.78015855754957497),
#  ('court', 0.77947526404844247),
#  ('steals', 0.7789140023173704),
#  ('rules', 0.77844476107184035),
#  ('invention', 0.77770456858800829),
#  ('instincts', 0.77770456858800829),
#  ('otto', 0.77770456858800829),
#  ('colors', 0.77684619943659217),
#  ('shares', 0.77652878949899629),
#  ('conventions', 0.77652878949899629),
#  ('reunion', 0.77318988823348167),
#  ('shared', 0.77318988823348167),
#  ('boxer', 0.77318988823348167),
#  ('attenborough', 0.77318988823348167),
#  ('delighted', 0.77318988823348167),
#  ('covers', 0.77139937745969345),
#  ('tale', 0.77010822169607374),
#  ('desires', 0.77010822169607374),
#  ('separated', 0.76913308753786735),
#  ('offbeat', 0.76913308753786735),
#  ('astounding', 0.76913308753786735),
#  ('principle', 0.76913308753786735),
#  ('rain', 0.7683706017975328),
#  ('forms', 0.7683706017975328),
#  ('denzel', 0.76804848873306297),
#  ('stays', 0.76787072675588186),
#  ('blob', 0.76725515271366718),
#  ('scarface', 0.76546784213957142),
#  ('des', 0.76546784213957142),
#  ('maria', 0.76214005204689672),
#  ('conventional', 0.76214005204689672),
#  ('rooney', 0.76214005204689672),
#  ('fresh', 0.76158434211317383),
#  ('midnight', 0.76096977689870637),
#  ('marries', 0.7591051483517427),
#  ('landscape', 0.75852993982279704),
#  ('animated', 0.75768570169751648),
#  ('titanic', 0.75666058628227129),
#  ('sunday', 0.75666058628227129),
#  ('stages', 0.75632608218147701),
#  ('boston', 0.75632608218147701),
#  ('museum', 0.75566753754127924),
#  ('aids', 0.75566753754127924),
#  ('spring', 0.7537718023763802),
#  ('cagney', 0.7537718023763802),
#  ('enjoyable', 0.75246375771636476),
#  ('immensely', 0.75198768058287868),
#  ('sung', 0.75141608868392118),
#  ('sir', 0.7507762933965817),
#  ('nevertheless', 0.75067102469813185),
#  ('truths', 0.75030559439989397),
#  ('stern', 0.75030559439989397),
#  ('driven', 0.74994477895307854),
#  ('comfort', 0.74923664721098893),
#  ('performances', 0.74883252516063137),
#  ('memories', 0.74721440183022114),
#  ('nowadays', 0.74721440183022114),
#  ('testament', 0.74721440183022114),
#  ('attend', 0.74721440183022114),
#  ('commitment', 0.74721440183022114),
#  ('realization', 0.74721440183022114),
#  ('simple', 0.74641420974143258),
#  ('golden', 0.74533293373051557),
#  ('leslie', 0.74533293373051557),
#  ('seeks', 0.74533293373051557),
#  ('domestic', 0.74533293373051557),
#  ('lovers', 0.74497224842453125),
#  ('relationship', 0.74484232345601786),
#  ('classy', 0.74444047494749577),
#  ('toby', 0.74444047494749577),
#  ('supporting', 0.74357803418683721),
#  ('che', 0.74262723782331497),
#  ('packed', 0.7410032017375805),
#  ('trek', 0.74021469141793106),
#  ('nations', 0.73966719619483823),
#  ('provoking', 0.73840377214806618),
#  ('strikes', 0.73759894313077912),
#  ('bondage', 0.73759894313077912),
#  ('depiction', 0.73682224406260699),
#  ('emotional', 0.73678211645681524),
#  ('secretary', 0.7366322924996842),
#  ('difficulty', 0.73570679497874125),
#  ('influenced', 0.73511137965897755),
#  ('florida', 0.73511137965897755),
#  ('christine', 0.73396917508020054),
#  ('germany', 0.73288750920945944),
#  ('unfold', 0.73236789371322664),
#  ('brings', 0.73142936713096229),
#  ('lewis', 0.73129894652432159),
#  ('elderly', 0.73088750854279239),
#  ('fathers', 0.73088750854279239),
#  ('retired', 0.72951482473082008),
#  ('polished', 0.72823850037121551),
#  ('willie', 0.72823850037121551),
#  ('owner', 0.72743625403857748),
#  ('streets', 0.72666987259858895),
#  ('henry', 0.72642196944481741),
#  ('portrays', 0.72593700338293632),
#  ('bears', 0.7252354951114458),
#  ('china', 0.72489587887452556),
#  ('anger', 0.72439972406404984),
#  ('society', 0.72433010799663333),
#  ('available', 0.72415741730250549),
#  ('faults', 0.72391883922669897),
#  ('best', 0.72347034060446314),
#  ('blues', 0.7230001437096264),
#  ('bugs', 0.72270598280148979),
#  ('obstacles', 0.72213471743319746),
#  ('enigmatic', 0.72213471743319746),
#  ('dominic', 0.72213471743319746),
#  ('remembers', 0.72054615474805961),
#  ('document', 0.72054615474805961),
#  ('strict', 0.72054615474805961),
#  ('anthology', 0.72054615474805961),
#  ('intricate', 0.71912266696320604),
#  ('magic', 0.71878961117328299),
#  ('delivers', 0.71846498854423513),
#  ('verhoeven', 0.71846498854423513),
#  ('jim', 0.71783979315031676),
#  ('bruno', 0.71783979315031676),
#  ('magician', 0.71783979315031676),
#  ('donald', 0.71667767797013937),
#  ('kent', 0.71667767797013937),
#  ('knightley', 0.71562003641200389),
#  ('endearing', 0.71465338578090898),
#  ('casual', 0.71465338578090898),
#  ('slimy', 0.71465338578090898),
#  ('relationships', 0.71393795022901896),
#  ('prejudice', 0.71376646776268093),
#  ('greatly', 0.71256526641704687),
#  ('whoopi', 0.71084675765934613),
#  ('showdown', 0.71084675765934613),
#  ('album', 0.71084675765934613),
#  ('charlie', 0.71024161391924534),
#  ('brad', 0.71024161391924534),
#  ('simon', 0.70967648251115578),
#  ('advanced', 0.70967648251115578),
#  ('effectively', 0.70914752190638641),
#  ('waves', 0.70914752190638641),
#  ('unsettling', 0.70818505792448583),
#  ('elephant', 0.70818505792448583),
#  ('march', 0.70774597998109789),
#  ('atmosphere', 0.70744773070214162),
#  ('influence', 0.70733181555190172),
#  ('genius', 0.706392407309966),
#  ('emotionally', 0.70556970055850243),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))
# Out:
# [('boll', -4.0778152602708904),
#  ('uwe', -3.9218753018711578),
#  ('thunderbirds', -3.6447082358007989),
#  ('beowulf', -3.6346396851769396),
#  ('dahmer', -3.5572016301387364),
#  ('wayans', -3.5197159818974928),
#  ('seagal', -3.3202501058581921),
#  ('gamera', -3.0853444322436783),
#  ('dreck', -3.0370818333726866),
#  ('unwatchable', -3.0269848170580955),
#  ('stinker', -2.9876839403711624),
#  ('mst', -2.7753833211707968),
#  ('incoherent', -2.7641396677532537),
#  ('flimsy', -2.7555911458712101),
#  ('dillinger', -2.6762095952465517),
#  ('yawn', -2.66353354771016),
#  ('unfunny', -2.5545257844967644),
#  ('ugh', -2.4922059522696118),
#  ('turd', -2.4922059522696118),
#  ('waste', -2.4907515123361046),
#  ('blah', -2.4475792789485005),
#  ('slugs', -2.4427317247372873),
#  ('tripe', -2.3838842974917549),
#  ('wtf', -2.3715779644809971),
#  ('horrid', -2.3715779644809971),
#  ('pointless', -2.3451073877136341),
#  ('atrocious', -2.3187369339642556),
#  ('damme', -2.3051524884992913),
#  ('redeeming', -2.2667790015910296),
#  ('prom', -2.2601040980178784),
#  ('baldwin', -2.2576634056025342),
#  ('drivel', -2.2476029585766928),
#  ('arquette', -2.2428658582924235),
#  ('lousy', -2.2118080125207054),
#  ('worst', -2.1930856334332267),
#  ('laughable', -2.172468615469592),
#  ('awful', -2.1385076866397488),
#  ('poorly', -2.1326133844207011),
#  ('unimaginative', -2.1278681355853104),
#  ('wasting', -2.1178155545614512),
#  ('remotely', -2.111046881095167),
#  ('camcorder', -2.0814106922997166),
#  ('excruciatingly', -2.0763693426428658),
#  ('nope', -2.0661963149298153),
#  ('chiba', -2.0402208285265546),
#  ('unoriginal', -2.0402208285265546),
#  ('unlikeable', -2.0024805005437076),
#  ('insipid', -2.0024805005437076),
#  ('existent', -2.0024805005437076),
#  ('embarrassingly', -1.9829714931972493),
#  ('embarrassment', -1.9811759026839282),
#  ('ariel', -1.9730493003694898),
#  ('rangers', -1.9670409306853867),
#  ('crocodile', -1.9593331693874538),
#  ('omen', -1.9548977855526928),
#  ('cannibal', -1.9425823589626385),
#  ('lundgren', -1.9369262352863008),
#  ('boredom', -1.9241486572738005),
#  ('miserably', -1.9216610938019989),
#  ('sucks', -1.9166645809588516),
#  ('quantum', -1.9155901669482822),
#  ('uninspired', -1.9131499212248517),
#  ('lame', -1.9117232884159072),
#  ('abysmal', -1.9110090970465483),
#  ('insult', -1.9085323769376259),
#  ('godzilla', -1.8884619221427668),
#  ('dumber', -1.8782515005814986),
#  ('snakes', -1.8782515005814986),
#  ('incompetent', -1.8782515005814986),
#  ('inane', -1.8782515005814986),
#  ('uninteresting', -1.8782515005814986),
#  ('gadget', -1.8686627800718458),
#  ('tooth', -1.8660293978158502),
#  ('appalling', -1.861401902283802),
#  ('hooper', -1.8589682189215049),
#  ('unconvincing', -1.8499866604307826),
#  ('unintentional', -1.8491655917638454),
#  ('horrible', -1.844894301366784),
#  ('amateurish', -1.8442230387637959),
#  ('pathetic', -1.8356498920533246),
#  ('idiotic', -1.8350451259946825),
#  ('timberlake', -1.8325814637483102),
#  ('porno', -1.8253403024917505),
#  ('dumbest', -1.8190859822734256),
#  ('stupidity', -1.8190859822734256),
#  ('snipes', -1.7984484573788515),
#  ('werewolves', -1.7905836901390428),
#  ('carlito', -1.7844180623696873),
#  ('cardboard', -1.7844180623696873),
#  ('wasted', -1.7773187850732606),
#  ('wretched', -1.7753727291132824),
#  ('whiny', -1.7719568419318752),
#  ('crap', -1.7677639636718392),
#  ('insulting', -1.7593184430601523),
#  ('dukes', -1.7529312977873708),
#  ('tedious', -1.74357739264197),
#  ('hackman', -1.7334905611040792),
#  ('moronic', -1.7334905611040792),
#  ('dreadful', -1.7153379479323672),
#  ('madsen', -1.7136170930460954),
#  ('dire', -1.7068932485848134),
#  ('anil', -1.6978488697781535),
#  ('badly', -1.6974777654416224),
#  ('suck', -1.69644928942373),
#  ('worse', -1.6820086052689358),
#  ('terrible', -1.6742829939664696),
#  ('excruciating', -1.6724960484012372),
#  ('lifeless', -1.6682784124570338),
#  ('hostel', -1.6512073253103952),
#  ('funding', -1.6512073253103952),
#  ('tomb', -1.6512073253103952),
#  ('embarrassing', -1.6487419623931301),
#  ('naschy', -1.6433394641097818),
#  ('mess', -1.6373136300125852),
#  ('pitiful', -1.6367300547221078),
#  ('garbage', -1.6342944202026248),
#  ('laughably', -1.6310994092152797),
#  ('springer', -1.6220166946409604),
#  ('shoddy', -1.6220166946409604),
#  ('pile', -1.6166064019127129),
#  ('stupid', -1.6042380193725321),
#  ('claus', -1.6035727929817023),
#  ('tolerable', -1.6020186945120718),
#  ('headache', -1.5979655112718634),
#  ('mutant', -1.5794984478354659),
#  ('barrel', -1.5763837141964829),
#  ('ashamed', -1.5751828878837815),
#  ('vampires', -1.5698920941993499),
#  ('worthless', -1.5696730802867105),
#  ('vomit', -1.5606477482646683),
#  ('severed', -1.5606477482646683),
#  ('filth', -1.5606477482646683),
#  ('tomatoes', -1.5478598502149123),
#  ('numbing', -1.5413978757024207),
#  ('arty', -1.5392336537608517),
#  ('dull', -1.5370486519863287),
#  ('inept', -1.5348897240782047),
#  ('avoid', -1.5285820410306898),
#  ('melody', -1.5283347592741248),
#  ('wooden', -1.5231262936001064),
#  ('stinks', -1.5146890573708685),
#  ('forgettable', -1.5061383425962966),
#  ('downhill', -1.5028281773758423),
#  ('horny', -1.5016335768276132),
#  ('fulci', -1.5016335768276132),
#  ('crappy', -1.4916548767777169),
#  ('missile', -1.4886094099905345),
#  ('bat', -1.4879845622768297),
#  ('incomprehensible', -1.4862640281428403),
#  ('serum', -1.4810829378523183),
#  ('morons', -1.4810829378523183),
#  ('unbelievably', -1.4751255748265062),
#  ('dinosaur', -1.4717991131070194),
#  ('whatsoever', -1.4673642120941253),
#  ('nonsensical', -1.4671216902538449),
#  ('excuse', -1.4656396376364811),
#  ('rubbish', -1.4643037391798193),
#  ('ridiculous', -1.4643037391798193),
#  ('muddled', -1.4600605113594998),
#  ('hackneyed', -1.4600605113594998),
#  ('junk', -1.4509012606635876),
#  ('flop', -1.4493657941636655),
#  ('boring', -1.4475226133603798),
#  ('turkey', -1.446672534434013),
#  ('shark', -1.4435550819833056),
#  ('topless', -1.4431166969865867),
#  ('hulk', -1.4421661446441447),
#  ('feeble', -1.4385450514637685),
#  ('cliched', -1.4385450514637685),
#  ('ridiculously', -1.4343891149692254),
#  ('useless', -1.4330865226266496),
#  ('seed', -1.4316446652648933),
#  ('rubber', -1.4282431163227363),
#  ('ripped', -1.4267476920415001),
#  ('lackluster', -1.4239163529094747),
#  ('simpson', -1.4239163529094747),
#  ('motions', -1.4165138466808813),
#  ('embarrassed', -1.414353536484412),
#  ('karate', -1.4104126705687794),
#  ('moron', -1.4104126705687794),
#  ('rambo', -1.4001533962834427),
#  ('tiresome', -1.3990063967082527),
#  ('costs', -1.3990063967082527),
#  ('stabbed', -1.3939425819581475),
#  ('hideous', -1.3939425819581475),
#  ('horrendous', -1.3921832261321399),
#  ('bikini', -1.3897786852025014),
#  ('inaccurate', -1.3862943611198906),
#  ('scifi', -1.3862943611198906),
#  ('bother', -1.3837974809213034),
#  ('dumb', -1.3830343745326832),
#  ('disjointed', -1.3824463525237174),
#  ('plastic', -1.379649818401222),
#  ('horribly', -1.3752572290729497),
#  ('fest', -1.3734048163938934),
#  ('brainless', -1.3686727597700712),
#  ('tossed', -1.3668919739731402),
#  ('spit', -1.3668919739731402),
#  ('inexplicably', -1.3629621296459706),
#  ('ludicrous', -1.3607089833017987),
#  ('inappropriate', -1.3603329246923941),
#  ('unintentionally', -1.3559342411129913),
#  ('sht', -1.3470736479666092),
#  ('olds', -1.3470736479666092),
#  ('tasteless', -1.3470736479666092),
#  ('sellers', -1.3470736479666092),
#  ('obnoxious', -1.3470736479666092),
#  ('mildly', -1.3470736479666092),
#  ('bland', -1.3470736479666092),
#  ('mummy', -1.3360821106198937),
#  ('travesty', -1.332824333059361),
#  ('annoying', -1.3279306437993517),
#  ('basket', -1.3268218420181135),
#  ('amateur', -1.3249586378868432),
#  ('christians', -1.3214180591988343),
#  ('bad', -1.3181383703873577),
#  ('dinosaurs', -1.3151764083944215),
#  ('inconsistent', -1.3144549701038171),
#  ('unless', -1.3136186458671415),
#  ('fails', -1.3117952384452776),
#  ('conveniently', -1.3061178831297879),
#  ('mediocre', -1.3050153046385489),
#  ('awake', -1.3023034140555041),
#  ('clichd', -1.2883176823703715),
#  ('clich', -1.2883176823703715),
#  ('meaningless', -1.2821438795837377),
#  ('meyer', -1.2790819028303235),
#  ('disappointment', -1.2744221771067286),
#  ('zombies', -1.274367217738176),
#  ('promptly', -1.2699939054237299),
#  ('asleep', -1.2651769826129404),
#  ('mormon', -1.2632725466072279),
#  ('redeem', -1.2632725466072279),
#  ('spacey', -1.2632725466072279),
#  ('skull', -1.2580997645370582),
#  ('miscast', -1.2575976455845737),
#  ('irritating', -1.2562305119428314),
#  ('utter', -1.254802083114237),
#  ('overacting', -1.2539956119462252),
#  ('disappointing', -1.252611464821114),
#  ('corpses', -1.2522458608392704),
#  ('meandering', -1.2496826112877859),
#  ('rave', -1.2485411238058124),
#  ('screaming', -1.248289421668791),
#  ('supposed', -1.2447538467688914),
#  ('pedestrian', -1.2410872101709427),
#  ('sickening', -1.2410872101709427),
#  ('kidding', -1.2410872101709427),
#  ('lampoon', -1.2378743560016172),
#  ('ta', -1.2354574363960786),
#  ('poor', -1.2354574363960786),
#  ('apes', -1.2347795759686935),
#  ('illogical', -1.2308258686705555),
#  ('unbelievable', -1.2297935039476786),
#  ('troma', -1.2289190722725134),
#  ('chopped', -1.2289190722725134),
#  ('surgery', -1.2275182763915262),
#  ('choppy', -1.2264456601779945),
#  ('randomly', -1.2255979869899984),
#  ('fake', -1.2249112115111065),
#  ('uh', -1.2183615417780356),
#  ('indulgent', -1.2183615417780356),
#  ('scarecrow', -1.2183615417780356),
#  ('dude', -1.2149889710456736),
#  ('dracula', -1.2132354284411879),
#  ('ham', -1.2110686273074049),
#  ('preposterous', -1.2102068851562526),
#  ('affleck', -1.2091142038263547),
#  ('joke', -1.2084501667221239),
#  ('clumsy', -1.2067880082765226),
#  ('random', -1.2063565956812121),
#  ('cheap', -1.2024325652844348),
#  ('consist', -1.195069467487792),
#  ('steer', -1.195069467487792),
#  ('naughty', -1.1936811182893885),
#  ('hopelessly', -1.1936811182893885),
#  ('idiots', -1.1924452991548684),
#  ('basinger', -1.1871747935191519),
#  ('devoid', -1.1832023569687291),
#  ('trite', -1.1821781444985158),
#  ('wannabe', -1.1818744589686192),
#  ('wander', -1.1780700610666661),
#  ('puerto', -1.1780700610666661),
#  ('derivative', -1.1780700610666661),
#  ('unbearable', -1.1711829815029451),
#  ('alright', -1.1689297133120902),
#  ('screw', -1.1651150017191891),
#  ('aiming', -1.1637091051584163),
#  ('redundant', -1.1637091051584163),
#  ('alleged', -1.1637091051584163),
#  ('pretentious', -1.1572551797584762),
#  ('scooby', -1.1559387838598278),
#  ('asylum', -1.1549136421723667),
#  ('sucked', -1.1529645246444826),
#  ('disgrace', -1.1516256436818493),
#  ('senseless', -1.1466719504885952),
#  ('bo', -1.1446562271695164),
#  ('dreary', -1.1431175286046611),
#  ('hack', -1.1422792353205962),
#  ('bin', -1.1409234867398326),
#  ('coherent', -1.1409234867398326),
#  ('idiot', -1.1398745209238483),
#  ('toilet', -1.1394342831883648),
#  ('doo', -1.1337381712886483),
#  ('repulsive', -1.1316521427463098),
#  ('werewolf', -1.1316521427463098),
#  ('cabin', -1.1287638038426984),
#  ('generous', -1.1215038924699356),
#  ('offensive', -1.1184981492417472),
#  ('monkey', -1.1183099709761579),
#  ('painfully', -1.1179789454394804),
#  ('unsympathetic', -1.1175713694107205),
#  ('renting', -1.1131620696828408),
#  ('tara', -1.1086626245216111),
#  ('lazy', -1.1077161029175804),
#  ('attract', -1.1063782146189787),
#  ('disgusting', -1.1043429633770947),
#  ('blame', -1.1004321253850955),
#  ('prequel', -1.0993818154471382),
#  ('chicks', -1.0980242263165552),
#  ('walked', -1.0956437262398278),
#  ('seconds', -1.0950337934660053),
#  ('wastes', -1.0936247471570706),
#  ('generic', -1.0936247471570706),
#  ('cheese', -1.0936247471570706),
#  ('bachchan', -1.0918907429077829),
#  ('sloppy', -1.0911123934362932),
#  ('demonic', -1.0890661615391191),
#  ('shouting', -1.087900633073182),
#  ('mins', -1.087900633073182),
#  ('huh', -1.087900633073182),
#  ('artsy', -1.0868633961790266),
#  ('retarded', -1.0850974692709436),
#  ('nerd', -1.0843396293813912),
#  ('lowest', -1.0830201939082735),
#  ('trash', -1.0819104390501781),
#  ('coffin', -1.0690534864265653),
#  ('insomnia', -1.0690534864265653),
#  ('dragons', -1.0690534864265653),
#  ('salman', -1.0690534864265653),
#  ('blatantly', -1.0690534864265653),
#  ('dud', -1.0690534864265653),
#  ('rats', -1.0690534864265653),
#  ('jaws', -1.0690534864265653),
#  ('shelf', -1.0690534864265653),
#  ('ugly', -1.0654102297007211),
#  ('oh', -1.060145138351082),
#  ('slightest', -1.0585558044674324),
#  ('puppets', -1.0486070575205098),
#  ('gimmick', -1.0486070575205098),
#  ('explanation', -1.0469296691557628),
#  ('excuses', -1.045649656692877),
#  ('boom', -1.0416919984154276),
#  ('failed', -1.0372036605394661),
#  ('cringe', -1.0337266055760017),
#  ('physics', -1.032392489363394),
#  ('bitten', -1.032392489363394),
#  ('clueless', -1.032392489363394),
#  ('blatant', -1.032392489363394),
#  ('token', -1.0301910090801158),
#  ('clue', -1.0291644308827645),
#  ('bored', -1.0280166413990575),
#  ('parsons', -1.0277082012401713),
#  ('cheated', -1.0277082012401713),
#  ('cgi', -1.025693523637347),
#  ('sat', -1.0254812024242803),
#  ('awfully', -1.0238582667460867),
#  ('paid', -1.0226960705295483),
#  ('unlikable', -1.0192175641696843),
#  ('warn', -1.0192175641696843),
#  ('fooled', -1.0157998557635173),
#  ('rotten', -1.0157998557635173),
#  ('painful', -1.0140391568647416),
#  ('yep', -1.0063370125589388),
#  ('subjected', -1.0053071993790035),
#  ('cue', -1.0020042501481849),
#  ('nowhere', -1.0002209555747281),
#  ('wandering', -0.99910468884970083),
#  ('bore', -0.99910468884970083),
#  ('absurd', -0.99856675750545654),
#  ('overlong', -0.99834016866353426),
#  ('flies', -0.99702812523036988),
#  ('paint', -0.99653885970600042),
#  ('porn', -0.99625628203058203),
#  ('paper', -0.99619622341335368),
#  ('predictable', -0.99614466563369874),
#  ('bargain', -0.99594289082177445),
#  ('ninja', -0.99594289082177445),
#  ('pseudo', -0.99035236589853903),
#  ('repetitive', -0.98714955037930274),
#  ('bashing', -0.98447224429022728),
#  ('stranded', -0.98447224429022728),
#  ('dismal', -0.98447224429022728),
#  ('outer', -0.98447224429022728),
#  ('brain', -0.98377532672827162),
#  ('sorry', -0.98361286453760466),
#  ('harold', -0.979804137596481),
#  ('vampire', -0.97897552454780112),
#  ('ignorant', -0.9776418499194458),
#  ('motivation', -0.97639465594386055),
#  ('unrealistic', -0.97426450283249755),
#  ('sentences', -0.9717478074334851),
#  ('shaggy', -0.9717478074334851),
#  ('kidnap', -0.9717478074334851),
#  ('cody', -0.9717478074334851),
#  ('scripting', -0.9717478074334851),
#  ('exposition', -0.9717478074334851),
#  ('wrestling', -0.9717478074334851),
#  ('overrated', -0.97009343786713131),
#  ('aliens', -0.96794458152070451),
#  ('halfway', -0.96737683678618958),
#  ('save', -0.96543738528113643),
#  ('santa', -0.9642025690144419),
#  ('mall', -0.96383167664315506),
#  ('security', -0.96125202862419823),
#  ('contrived', -0.95843136650259653),
#  ('freaking', -0.95451194469435285),
#  ('btw', -0.95451194469435285),
#  ('sums', -0.95451194469435285),
#  ('lacks', -0.952073751649542),
#  ('whale', -0.95069951155969701),
#  ('gore', -0.94853321111328437),
#  ('bunch', -0.94848710420218474),
#  ('hype', -0.94790777328643205),
#  ('flat', -0.94295575377929441),
#  ('noise', -0.94160853985844484),
#  ('below', -0.94160853985844484),
#  ('messing', -0.93916951425908624),
#  ('clone', -0.93916951425908624),
#  ('plain', -0.93887392037927409),
#  ('spending', -0.93791460425967188),
#  ('bothered', -0.93559348412868382),
#  ('mute', -0.92984369827885838),
#  ('annoyed', -0.92984369827885838),
#  ('sounded', -0.92677860875410745),
#  ('honestly', -0.92629501555053162),
#  ('lance', -0.92542321543742767),
#  ('dolph', -0.923575264288784),
#  ('minutes', -0.91926883385924085),
#  ('murray', -0.9167145504861357),
#  ('contempt', -0.91303516741438884),
#  ('wreck', -0.91303516741438884),
#  ('lesbian', -0.9115721521721607),
#  ('chick', -0.90917326410529098),
#  ('phony', -0.9077209997703467),
#  ('dollar', -0.9077209997703467),
#  ('min', -0.90649042727586293),
#  ('f', -0.90624205165116323),
#  ('secondly', -0.9045181956488878),
#  ('wanna', -0.9045181956488878),
#  ('remove', -0.90181271269350194),
#  ('messy', -0.90181271269350194),
#  ('stale', -0.8993711860155531),
#  ('carradine', -0.89879757442663788),
#  ('rat', -0.89787166558102183),
#  ('errors', -0.89787166558102183),
#  ('shallow', -0.89685713745244844),
#  ('assuming', -0.89159811928378352),
#  ('misleading', -0.89159811928378352),
#  ('synopsis', -0.89159811928378352),
#  ('breasts', -0.88630989966221918),
#  ('gray', -0.88600682711039258),
#  ('splatter', -0.88484589916649681),
#  ('stilted', -0.88434382559213143),
#  ('chest', -0.88434382559213143),
#  ('yeah', -0.88423431575803901),
#  ('indication', -0.88226098328784364),
#  ('filler', -0.88226098328784364),
#  ('clay', -0.88005064685901147),
#  ('nonsense', -0.87977066029653739),
#  ('originals', -0.87850035509371982),
#  ('daylight', -0.87850035509371982),
#  ('button', -0.87755787460398593),
#  ('unnecessary', -0.87612648787092673),
#  ('swear', -0.87369253795264423),
#  ('grave', -0.87369253795264423),
#  ('ruined', -0.87369253795264423),
#  ('somebody', -0.87119618756679917),
#  ('yelling', -0.86966741578981333),
#  ('elvis', -0.86966741578981333),
#  ('mindless', -0.86966741578981333),
#  ('orange', -0.86789096396187737),
#  ('irrelevant', -0.86789096396187737),
#  ('mouths', -0.86689025337390802),
#  ('commits', -0.86689025337390802),
#  ('terribly', -0.86689025337390802),
#  ('continuity', -0.86608246300004088),
#  ('hoping', -0.86330768944468717),
#  ('ha', -0.86224359919456472),
#  ('nudity', -0.86100776531401546),
#  ('endless', -0.85997265771399223),
#  ('chased', -0.85734819624070502),
#  ('revolt', -0.85652731292421014),
#  ('nut', -0.85544415910796867),
#  ('behave', -0.84884133949568752),
#  ('minus', -0.8482073647700441),
#  ('decent', -0.84602416208146713),
#  ('torture', -0.84440895553308559),
#  ('ants', -0.84397007029452897),
#  ('schlock', -0.84397007029452897),
#  ('rented', -0.84357929264203757),
#  ('disaster', -0.84314719429664609),
#  ('mysteriously', -0.84152508130146253),
#  ('professionals', -0.84152508130146253),
#  ('drab', -0.84152508130146253),
#  ('downright', -0.84152508130146253),
#  ('ok', -0.8411845531731027),
#  ('fat', -0.83775590115788334),
#  ('bronson', -0.83683991530993773),
#  ('severely', -0.83683991530993773),
#  ('unpleasant', -0.83683991530993773),
#  ('stretched', -0.835335793734022),
#  ('figured', -0.83415231962639969),
#  ('switched', -0.83240924789345294),
#  ('whining', -0.83240924789345294),
#  ('rip', -0.83140148805808889),
#  ('hopkins', -0.8302829447321437),
#  ('throwing', -0.8295867791837136),
#  ('attempt', -0.82556118527256561),
#  ('sticking', -0.82423258745620753),
#  ('crazed', -0.82423258745620753),
#  ('tacky', -0.82423258745620753),
#  ('weak', -0.8236227867201853),
#  ('slap', -0.820452150472331),
#  ('jesus', -0.81940663381349643),
#  ('whats', -0.81923382673488843),
#  ('lois', -0.81786597780568482),
#  ('lester', -0.81786597780568482),
#  ('goldie', -0.81546752126118083),
#  ('parking', -0.81546752126118083),
#  ('christian', -0.81429794963546309),
#  ('barely', -0.81365648103016064),
#  ('apparently', -0.81261259786572149),
#  ('haired', -0.81201571081285062),
#  ('implausible', -0.81145667055857473),
#  ('nothing', -0.81049650887674252),
#  ('huston', -0.81016963596561464),
#  ('sorely', -0.81016963596561464),
#  ('clichs', -0.81016963596561464),
#  ('credibility', -0.80926493689726764),
#  ('hybrid', -0.80766631776345477),
#  ('bible', -0.80705475679622996),
#  ('explained', -0.80478082085572145),
#  ('messed', -0.80407874126722689),
#  ('presumably', -0.80251070381482459),
#  ('dump', -0.80067807145932124),
#  ('banal', -0.79850769621777162),
#  ('misguided', -0.79850769621777162),
#  ('celluloid', -0.79850769621777162),
#  ('couldn', -0.79696597303708028),
#  ('money', -0.79601605681206233),
#  ('snake', -0.79505047583391386),
#  ('damned', -0.79438185230421376),
#  ('unsuspecting', -0.79438185230421376),
#  ('hollow', -0.7917793276890871),
#  ('muslims', -0.7886796072815091),
#  ('breast', -0.7886796072815091),
#  ('creek', -0.7886796072815091),
#  ('caricatures', -0.7886796072815091),
#  ('advise', -0.7886796072815091),
#  ('load', -0.7886796072815091),
#  ('sake', -0.7886796072815091),
#  ('total', -0.78700635878188829),
#  ('priest', -0.78556981359780187),
#  ('passable', -0.78432306122581497),
#  ('supposedly', -0.78385925223259312),
#  ('uma', -0.78349098981936893),
#  ('slapped', -0.78226603988913979),
#  ('pad', -0.78226603988913979),
#  ('inducing', -0.78028395726132005),
#  ('disguise', -0.77874953213940223),
#  ('guessed', -0.77810533089443001),
#  ('spaghetti', -0.77652878949899629),
#  ('cape', -0.77652878949899629),
#  ('psychic', -0.77652878949899629),
#  ('consists', -0.77652878949899629),
#  ('zombie', -0.77631610047082156),
#  ('bomb', -0.77388118403394157),
#  ('terrorists', -0.77302861091678676),
#  ('ape', -0.77207179207483223),
#  ('bottom', -0.77207179207483223),
#  ('unattractive', -0.77136615542018938),
#  ('pray', -0.77136615542018938),
#  ('cliches', -0.77136615542018938),
#  ('christ', -0.77136615542018938),
#  ('unfortunately', -0.77048254067171962),
#  ('bullets', -0.76897398146885909),
#  ('grade', -0.7673133927012592),
#  ('mason', -0.76669586858275751),
#  ('christianity', -0.76669586858275751),
#  ('drags', -0.76452384340217305),
#  ('freak', -0.76187553676959741),
#  ('wolf', -0.75964746405302197),
#  ('fx', -0.75964746405302197),
#  ('recycled', -0.75857498588240069),
#  ('offended', -0.75857498588240069),
#  ('agreed', -0.75711755711129236),
#  ('shockingly', -0.75617333239121076),
#  ('script', -0.75553540480209191),
#  ('raped', -0.75551182107839776),
#  ('producers', -0.75514886284872718),
#  ('okay', -0.75476155582444937),
#  ('confusing', -0.75434736480605891),
#  ('stomach', -0.7531741549162505),
#  ('monster', -0.75284517169759568),
#  ('intentional', -0.75175460751341661),
#  ('unsatisfying', -0.75175460751341661),
#  ('snl', -0.74932275884041755),
#  ('blond', -0.74932275884041755),
#  ('seriously', -0.74913839263329918),
#  ('infected', -0.748738195959881),
#  ('snuff', -0.74778366952338893),
#  ('alas', -0.74594536612691609),
#  ('promising', -0.7448853477953461),
#  ('jill', -0.7441957068640318),
#  ('crashes', -0.7441957068640318),
#  ('disgust', -0.7441957068640318),
#  ('freeze', -0.7441957068640318),
#  ('knife', -0.74371119429841048),
#  ('wanders', -0.74093784439629373),
#  ('milo', -0.74093784439629373),
#  ('feed', -0.74093784439629373),
#  ('substance', -0.74093784439629373),
#  ('premise', -0.7400748826582384),
#  ('threw', -0.73912312654050327),
#  ('k', -0.73830244953853796),
#  ('doctors', -0.73796651551282078),
#  ('tunnel', -0.73796651551282078),
#  ('dear', -0.73396917508020054),
#  ('z', -0.73099740469104302),
#  ('write', -0.73086726583269768),
#  ('rental', -0.72856144879524476),
#  ('schneider', -0.72632304279884485),
#  ('overboard', -0.72632304279884485),
#  ('warned', -0.72448043757149894),
#  ('cheaply', -0.72360638804465394),
#  ('glaring', -0.72360638804465394),
#  ('zero', -0.72340891179053157),
#  ('semi', -0.72252557949472529),
#  ('guess', -0.72192630932305224),
#  ('scientist', -0.72158259656890578),
#  ('youtube', -0.72115480554684885),
#  ('screenwriters', -0.72115480554684885),
#  ('arab', -0.72115480554684885),
#  ('males', -0.72115480554684885),
#  ('logic', -0.72057883502061604),
#  ('ripping', -0.71893129771565989),
#  ('vague', -0.71893129771565989),
#  ('slasher', -0.71851118965769023),
#  ('cave', -0.7182353937779874),
#  ('throw', -0.71756042041380808),
#  ('accents', -0.71690544717879778),
#  ('alien', -0.71690544717879778),
#  ('silly', -0.71660965307300073),
#  ('zombi', -0.71505201594799517),
#  ('clown', -0.71446876911307267),
#  ('chainsaw', -0.71334988787746478),
#  ('suspension', -0.71334988787746478),
#  ('skip', -0.71216176892581851),
#  ('instead', -0.71048388522675199),
#  ('disliked', -0.710331017660213),
#  ('billed', -0.710331017660213),
#  ('blank', -0.70942350246511354),
#  ('throat', -0.70942350246511354),
#  ('lab', -0.70694986603199717),
#  ('losers', -0.70657020089208611),
#  ('par', -0.70590799306707896),
#  ('advertising', -0.70548099481555382),
#  ('gag', -0.70479368594626879),
#  ('execution', -0.70446094046021868),
#  ('nose', -0.70350365448410634),
#  ('hated', -0.70319751641344685),
#  ('effort', -0.7031596856305341),
#  ('galactica', -0.70175555509654541),
#  ('indicate', -0.70175555509654541),
#  ('sided', -0.70175555509654541),
#  ('populated', -0.70019901341719004),
#  ('shoot', -0.6989705551531219),
#  ('fill', -0.698804176875086),
#  ('gratuitous', -0.69815972238348956),
#  ('polly', -0.69754708988255432),
#  ('rampage', -0.69640830620807681),
#  ('dim', -0.69640830620807681),
#  ('burn', -0.69640830620807681),
#  ('alley', -0.69537187558205638),
#  ('cohen', -0.69442459184712646),
#  ('hammy', -0.69355542714655027),
#  ('hyped', -0.69355542714655027),
#  ('eaten', -0.68954711121599011),
#  ('experiments', -0.68954711121599011),
#  ('none', -0.6890744434562236),
#  ('trashy', -0.68808538621798288),
#  ('cameras', -0.68650263784127685),
#  ('assume', -0.6861586701708462),
#  ('stick', -0.68591226926547233),
#  ('reasonable', -0.68583222802818422),
#  ('failure', -0.68522682234249099),
#  ('pie', -0.68371809027109365),
#  ('rent', -0.68354539249393242),
#  ('dubbing', -0.68290851292742361),
#  ('weren', -0.6823244986655489),
#  ('truck', -0.68175927810915338),
#  ('stock', -0.67909433911359085),
#  ('thin', -0.67742086740323382),
#  ('incorrect', -0.67334455326376552),
#  ('havoc', -0.67334455326376552),
#  ('swearing', -0.67334455326376552),
#  ('arguments', -0.67334455326376552),
#  ('cyborg', -0.67334455326376552),
#  ('exit', -0.67334455326376552),
#  ('exorcist', -0.67334455326376552),
#  ('advertised', -0.67334455326376552),
#  ('hum', -0.67334455326376552),
#  ('tempted', -0.67334455326376552),
#  ('inexplicable', -0.67334455326376552),
#  ('skits', -0.67334455326376552),
#  ('daddy', -0.67334455326376552),
#  ('holy', -0.67334455326376552),
#  ('exercise', -0.67334455326376552),
#  ('pg', -0.67334455326376552),
#  ('arm', -0.67334455326376552),
#  ('tried', -0.67334455326376552),
#  ('suppose', -0.66965178688128146),
#  ('advice', -0.66769354365053246),
#  ('gonna', -0.66727362641004917),
#  ('disbelief', -0.66500004556549575),
#  ('derek', -0.6636845090562784),
#  ('mean', -0.66114247745030508),
#  ('merit', -0.66035735773695436),
#  ('looked', -0.6602804413162221),
#  ('channel', -0.66009406126360604),
#  ('cliche', -0.65837421380490035),
#  ('destroying', -0.65790261578630349),
#  ('gross', -0.65713674303691227),
#  ('stereotypical', -0.65686428574290745),
#  ('mentioning', -0.65629093397016425),
#  ('vulgar', -0.65501559439760593),
#  ('bitch', -0.65353407972260258),
#  ('hoped', -0.65312550621045939),
#  ('lacking', -0.65225562324184638),
#  ('shaking', -0.65179199487803152),
#  ('spent', -0.65155245096848746),
#  ('stiff', -0.65130752221703647),
#  ('insults', -0.64971396410271642),
#  ('corn', -0.64971396410271642),
#  ('overdone', -0.64913029514317111),
#  ('low', -0.64892927799573152),
#  ('romero', -0.6485170615432827),
#  ('hour', -0.64745553340521167),
#  ('clive', -0.64719243522532),
#  ('predictably', -0.64719243522532),
#  ('trace', -0.64719243522532),
#  ('blair', -0.64719243522532),
#  ('saved', -0.64691036448575012),
#  ('damage', -0.64647566125079858),
#  ('reason', -0.64625116218498069),
#  ('intentions', -0.64622792432632514),
#  ('starters', -0.64571848698883449),
#  ('statements', -0.64571848698883449),
#  ('um', -0.64571848698883449),
#  ('sentence', -0.64571848698883449),
#  ('hardcore', -0.64491739746429821),
#  ('makeup', -0.64491739746429821),
#  ('lack', -0.64431614250687563),
#  ('hurts', -0.64406845773896548),
#  ('makers', -0.6435343096390499),
#  ('airport', -0.64220878785222379),
#  ('empty', -0.64153525562181912),
#  ('holes', -0.63738670049736545),
#  ('cancer', -0.63487827243596939),
#  ('automatically', -0.63487827243596939),
#  ('wouldn', -0.63455207910916711),
#  ('proof', -0.63410844945722766),
#  ('demon', -0.63363158379078399),
#  ('toys', -0.63275456577104972),
#  ('doll', -0.63160226623006877),
#  ('utterly', -0.63160226623006877),
#  ('originality', -0.63087893366086323),
#  ('bush', -0.63069416591339544),
#  ('saying', -0.63015728557783457),
#  ('cover', -0.62900613725015142),
#  ('meat', -0.6277162006393544),
#  ('forest', -0.6277162006393544),
#  ('deserve', -0.6277162006393544),
#  ('sum', -0.62685049715796837),
#  ('bucks', -0.62662891309693258),
#  ('jumped', -0.62625487437208349),
#  ('hills', -0.62595130223645967),
#  ('watchable', -0.62595130223645967),
#  ('misfortune', -0.62548853208613053),
#  ('lacked', -0.62548853208613053),
#  ('handed', -0.62548853208613053),
#  ('mistake', -0.62548853208613053),
#  ('please', -0.62460467733430325),
#  ('mtv', -0.62303213193180695),
#  ('whoever', -0.62303213193180695),
#  ('sadistic', -0.62170685608049914),
#  ('fury', -0.62124944138036375),
#  ('monsters', -0.62087763196558421),
#  ('sources', -0.62030985660767901),
#  ('screenwriter', -0.61933574832671323),
#  ('neither', -0.61913661574756695),
#  ('rational', -0.61727605778784256),
#  ('rice', -0.61727605778784256),
#  ('intro', -0.61727605778784256),
#  ('nuclear', -0.61727605778784256),
#  ('sequels', -0.61505299482664821),
#  ('flesh', -0.61458705284663162),
#  ('lying', -0.61387399966543743),
#  ('creature', -0.61335398426126342),
#  ('stalker', -0.61264631271869296),
#  ('annie', -0.61162704334459994),
#  ('wig', -0.6100322738494387),
#  ('dust', -0.6100322738494387),
#  ('potentially', -0.6100322738494387),
#  ('propaganda', -0.60911014736056435),
#  ('leonard', -0.60835287132188354),
#  ('thats', -0.60804721079219848),
#  ('racist', -0.60791900171892344),
#  ('mon', -0.60718286317385817),
#  ('convince', -0.60718286317385817),
#  ('asian', -0.60608204157465728),
#  ('why', -0.60603765596200732),
#  ('rex', -0.60565972643682953),
#  ('satan', -0.60565972643682953),
#  ('remake', -0.60359517405530438),
#  ('tarantino', -0.60323876946104049),
#  ('fail', -0.60214735225674265),
#  ('ears', -0.60063812303533215),
#  ('ah', -0.60063812303533215),
#  ('loser', -0.60063812303533215),
#  ('bergman', -0.59841436797720216),
#  ('favor', -0.59806011543749205),
#  ('jenna', -0.59685468240550987),
#  ('vince', -0.59685468240550987),
#  ('daisy', -0.59685468240550987),
#  ('except', -0.59625292042833478),
#  ('flick', -0.59601380565791773),
#  ('jews', -0.59481127983908344),
#  ('refer', -0.59481127983908344),
#  ('outs', -0.59481127983908344),
#  ('acid', -0.59353195105624934),
#  ('freddy', -0.59320557603540169),
#  ('lowe', -0.59265564201362297),
#  ('relies', -0.59265564201362297),
#  ('spare', -0.59265564201362297),
#  ('dialog', -0.59224146257481725),
#  ('lou', -0.59201782587438712),
#  ('unexplained', -0.5915328033598346),
#  ('compelled', -0.59084396526464977),
#  ('dragged', -0.58978866757279214),
#  ('guy', -0.58871839653918601),
#  ('problem', -0.58831715702588649),
#  ('vanessa', -0.58796849961486664),
#  ('lift', -0.58796849961486664),
#  ('mentions', -0.58796849961486664),
#  ('melting', -0.58796849961486664),
#  ('flash', -0.58628264187283141),
#  ('im', -0.58578866223944603),
#  ('landing', -0.58488521779629055),
#  ('sleaze', -0.58407926011379696),
#  ('least', -0.58390949898427402),
#  ('mouth', -0.58189706594518475),
#  ('cents', -0.57981849525294205),
#  ('ally', -0.57981849525294205),
#  ('swallow', -0.57981849525294205),
#  ('imaginable', -0.57799799593347234),
#  ('sole', -0.57753173459487472),
#  ('hell', -0.57711652116921186),
#  ('jerk', -0.5767444073725202),
#  ('drink', -0.57610516012828095),
#  ('axe', -0.57513025412948648),
#  ('lo', -0.57513025412948648),
#  ('incapable', -0.57513025412948648),
#  ('intent', -0.57513025412948648),
#  ('fist', -0.5741355854710487),
#  ('evidently', -0.5741355854710487),
#  ('shower', -0.57376887002711885),
#  ('fifteen', -0.57231658460114743),
#  ('wasn', -0.57113814502039062),
#  ('didnt', -0.56994674677378798),
#  ('disgusted', -0.56994674677378798),
#  ('rapist', -0.56994674677378798),
#  ('solely', -0.56994674677378798),
#  ('promised', -0.56994674677378798),
#  ('thugs', -0.56994674677378798),
#  ('corpse', -0.56994674677378798),
#  ('virus', -0.56994674677378798),
#  ('idea', -0.56785412355062381),
#  ('budget', -0.56778465568921843),
#  ('staring', -0.56673120652605846),
#  ('pc', -0.5653882304239134),
#  ('mermaid', -0.5653882304239134),
#  ('minimal', -0.56485677065087991),
#  ('reasonably', -0.56485677065087991),
#  ('naked', -0.56436905973672824),
#  ('inaccuracies', -0.5641850345910131),
#  ('rick', -0.5641850345910131),
#  ('category', -0.5641850345910131),
#  ('firstly', -0.56330904028151818),
#  ('cheesy', -0.56177413514792773),
#  ('judging', -0.56105621879741929),
#  ('label', -0.56040878520148829),
#  ('stare', -0.56040878520148829),
#  ('half', -0.56018599518206891),
#  ('assault', -0.55965964854640815),
#  ('pregnant', -0.55965964854640815),
#  ('no', -0.55924503152672689),
#  ('millions', -0.55774254355374242),
#  ('stereotypes', -0.55636159489889891),
#  ('juvenile', -0.55620611452642787),
#  ('weekend', -0.5552830824113747),
#  ('stalking', -0.55494721551898296),
#  ('convoluted', -0.55494721551898296),
#  ('laurel', -0.55494721551898296),
#  ('killings', -0.55389687800152465),
#  ('grudge', -0.55300723780228545),
#  ('sequel', -0.55170737150546834),
#  ('hire', -0.55118755010439224),
#  ('somewhere', -0.55105223640983103),
#  ('frankly', -0.54978620815406709),
#  ('attacking', -0.54892984331316819),
#  ('volume', -0.54892984331316819),
#  ('arguing', -0.54892984331316819),
#  ('contribute', -0.54892984331316819),
#  ('rescued', -0.54892984331316819),
#  ('paying', -0.54853335775590772),
#  ('someone', -0.54805145790464505),
#  ('cant', -0.54568548888348367),
#  ('cash', -0.54552676426718449),
#  ('research', -0.54399893169058933),
#  ('dimensional', -0.54377565028662089),
#  ('walk', -0.54377565028662089),
#  ('editing', -0.54326238251767855),
#  ('horrified', -0.54226714960080968),
#  ('skinny', -0.54226714960080968),
#  ('duration', -0.54226714960080968),
#  ('leigh', -0.54226714960080968),
#  ('franco', -0.54226714960080968),
#  ('formulaic', -0.54226714960080968),
#  ('conceived', -0.54226714960080968),
#  ('scare', -0.54226714960080968),
#  ('positive', -0.54003600186579181),
#  ('anything', -0.5389965007326869),
#  ('waited', -0.53824736688362484),
#  ('letters', -0.53824736688362484),
#  ('minimum', -0.53772746502938207),
#  ('glowing', -0.537053101602876),
#  ('corey', -0.53484926824624057),
#  ('cap', -0.53484926824624057),
#  ('eli', -0.53484926824624057),
#  ('sarcasm', -0.53484926824624057),
#  ('balls', -0.53397282095664211),
#  ('kicking', -0.53397282095664211),
#  ('sit', -0.53358828173563289),
#  ('either', -0.53297221221022828),
#  ('twins', -0.53286151216517119),
#  ('root', -0.53286151216517119),
#  ('exceptions', -0.53140633146601135),
#  ('wrong', -0.53127551931860884),
#  ('god', -0.53046899481461596),
#  ('looks', -0.52965227228496048),
#  ('expects', -0.52941845684260658),
#  ('sized', -0.52941845684260658),
#  ('failing', -0.52941845684260658),
#  ('shut', -0.52858361378634644),
#  ('sadly', -0.52819166151937191),
#  ('thing', -0.52814128682752848),
#  ('helicopter', -0.52653984579872681),
#  ('ad', -0.52653984579872681),
#  ('writers', -0.52601983850690703),
#  ('victims', -0.52494152232776148),
#  ('franchise', -0.52486935517706257),
#  ('defense', -0.52455581657789274),
#  ('props', -0.52409738486472734),
#  ('dry', -0.52392474246885068),
#  ('string', -0.52377834758889663),
#  ('sleep', -0.52336344167323223),
#  ('saving', -0.52280181481270649),
#  ('basically', -0.52273453223003907),
#  ('adaption', -0.52199892436411588),
#  ('kapoor', -0.52199892436411588),
#  ('experiment', -0.52199892436411588),
#  ('competent', -0.52042208465425133),
#  ('avoided', -0.51984049486220618),
#  ('akshay', -0.51984049486220618),
#  ('deaths', -0.51984049486220618),
#  ('josh', -0.51935243999515235),
#  ('plot', -0.5186580625548155),
#  ('altered', -0.51857918229943911),
#  ('cartoonish', -0.51857918229943911),
#  ('loosely', -0.5163966688154461),
#  ('killing', -0.51624362320755623),
#  ('hepburn', -0.51591099614926994),
#  ('sooner', -0.51591099614926994),
#  ('aim', -0.51591099614926994),
#  ('khan', -0.51533312178618684),
#  ('tired', -0.51500099517647124),
#  ('expense', -0.51377113399574748),
#  ('posing', -0.51377113399574748),
#  ...]

# %% [markdown]
# ## Creating the Input/Output Data (Transforming Text into Numbers)

# %%
# Total number of words in the reviews

vocab = set(total_counts.keys())
vocab_size = len(vocab)

# Vectorize each input data to the below format
'''
layer_0:
 -----------------------------------------------
|  0  |  1  |  3  |    | n - 3  | n - 2  | n - 1|
 -----------------------------------------------
|word1|word2|word3|....|word n-2|word n-1|word n|
 -----------------------------------------------
'''

layer_0 = np.zeros((1,vocab_size))

# Save the index of each word in a dictonary

word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
word2index
# Out:
# {'': 0,
#  'uranus': 1,
#  'misanthrope': 2,
#  'sciamma': 3,
#  'excrements': 4,
#  'westcourt': 5,
#  'dyer': 6,
#  'reactionary': 7,
#  'itz': 8,
#  'mab': 9,
#  'anywhozitz': 10,
#  'rosselini': 11,
#  'sagramore': 12,
#  'millenial': 13,
#  'movieeven': 14,
#  'underfoot': 15,
#  'windshields': 16,
#  'coulisses': 17,
#  'stevens': 18,
#  'mentoring': 19,
#  'parody': 20,
#  'suffocatingly': 21,
#  'oberon': 22,
#  'plana': 23,
#  'twined': 24,
#  'ayatollahs': 25,
#  'mcfadden': 26,
#  'amrohi': 27,
#  'nads': 28,
#  'barcoded': 29,
#  'inquest': 30,
#  'wanted': 31,
#  'negotiatior': 32,
#  'wickes': 33,
#  'shigeru': 34,
#  'stoolie': 35,
#  'tidende': 36,
#  'childen': 37,
#  'calico': 38,
#  'overdose': 39,
#  'suavely': 40,
#  'gimmicks': 41,
#  'clank': 42,
#  'arold': 43,
#  'neighbors': 44,
#  'unravelled': 45,
#  'bianlian': 46,
#  'reconsidered': 47,
#  'asif': 48,
#  'brownie': 49,
#  'telling': 50,
#  'characterized': 51,
#  'kewl': 52,
#  'verhooven': 53,
#  'analyses': 54,
#  'heroe': 55,
#  'kinear': 56,
#  'cripplingly': 57,
#  'settling': 58,
#  'madelein': 59,
#  'teleporter': 60,
#  'gayniggers': 61,
#  'macist': 62,
#  'beretta': 63,
#  'ingrid': 64,
#  'understudies': 65,
#  'chintzy': 66,
#  'voorhess': 67,
#  'azteca': 68,
#  'pamphlet': 69,
#  'cher': 70,
#  'pessimistic': 71,
#  'preaching': 72,
#  'barking': 73,
#  'eislin': 74,
#  'beeru': 75,
#  'nibelungos': 76,
#  'lockley': 77,
#  'electro': 78,
#  'teasingly': 79,
#  'rinna': 80,
#  'tranquilizer': 81,
#  'mustafa': 82,
#  'chitre': 83,
#  'werdegast': 84,
#  'sexes': 85,
#  'vigor': 86,
#  'iii': 87,
#  'dk': 88,
#  'camacho': 89,
#  'mapped': 90,
#  'ritualized': 91,
#  'tweedy': 92,
#  'siberian': 93,
#  'attonment': 94,
#  'klux': 95,
#  'connectivity': 96,
#  'glitz': 97,
#  'seducing': 98,
#  'harem': 99,
#  'freeloader': 100,
#  'arrivals': 101,
#  'tetsuro': 102,
#  'nauseous': 103,
#  'safar': 104,
#  'smithee': 105,
#  'albaladejo': 106,
#  'ignored': 107,
#  'jap': 108,
#  'uncompleted': 109,
#  'grapewin': 110,
#  'followings': 111,
#  'assassinating': 112,
#  'adorned': 113,
#  'mantle': 114,
#  'conman': 115,
#  'shimmy': 116,
#  'veterinarian': 117,
#  'veal': 118,
#  'civic': 119,
#  'harpy': 120,
#  'presumptive': 121,
#  'horns': 122,
#  'leartes': 123,
#  'renew': 124,
#  'mankind': 125,
#  'sartorius': 126,
#  'inmho': 127,
#  'deewaar': 128,
#  'seasoned': 129,
#  'shuts': 130,
#  'prisoner': 131,
#  'auberjonois': 132,
#  'grifts': 133,
#  'thickly': 134,
#  'wolverines': 135,
#  'broadways': 136,
#  'dramatism': 137,
#  'bandolero': 138,
#  'seppuku': 139,
#  'vitam': 140,
#  'colorado': 141,
#  'seftel': 142,
#  'manifestations': 143,
#  'beth': 144,
#  'fallacies': 145,
#  'cludia': 146,
#  'ravages': 147,
#  'girlfight': 148,
#  'prefigures': 149,
#  'madcaps': 150,
#  'loiret': 151,
#  'ethnicities': 152,
#  'variables': 153,
#  'trough': 154,
#  'menu': 155,
#  'estoril': 156,
#  'pheebs': 157,
#  'repairman': 158,
#  'avenue': 159,
#  'heian': 160,
#  'darnedest': 161,
#  'groin': 162,
#  'alleyway': 163,
#  'sur': 164,
#  'royston': 165,
#  'harel': 166,
#  'flashiness': 167,
#  'ravenously': 168,
#  'territories': 169,
#  'singing': 170,
#  'curtis': 171,
#  'desolate': 172,
#  'bottled': 173,
#  'tanaaz': 174,
#  'quills': 175,
#  'partook': 176,
#  'korty': 177,
#  'confirm': 178,
#  'provoker': 179,
#  'feedings': 180,
#  'seeber': 181,
#  'wachs': 182,
#  'pdi': 183,
#  'unused': 184,
#  'tetanus': 185,
#  'modifies': 186,
#  'ashknenazi': 187,
#  'piere': 188,
#  'edwardian': 189,
#  'bandekar': 190,
#  'tearjerker': 191,
#  'essay': 192,
#  'orb': 193,
#  'giger': 194,
#  'outlaw': 195,
#  'thirdly': 196,
#  'applicability': 197,
#  'choosened': 198,
#  'groins': 199,
#  'bakersfield': 200,
#  'edith': 201,
#  'balkanski': 202,
#  'dears': 203,
#  'lo': 204,
#  'buttgereit': 205,
#  'ia': 206,
#  'hecq': 207,
#  'spank': 208,
#  'turaqistan': 209,
#  'psilcybe': 210,
#  'maclaren': 211,
#  'pretensions': 212,
#  'strudel': 213,
#  'schleimli': 214,
#  'utterless': 215,
#  'keene': 216,
#  'shock': 217,
#  'atlantis': 218,
#  'observably': 219,
#  'hallie': 220,
#  'daltry': 221,
#  'ibm': 222,
#  'gillham': 223,
#  'exaggerations': 224,
#  'cacoyanis': 225,
#  'skers': 226,
#  'crystallized': 227,
#  'combustion': 228,
#  'naturalness': 229,
#  'touching': 230,
#  'caterpillar': 231,
#  'eraserhead': 232,
#  'hairspray': 233,
#  'aldar': 234,
#  'wedged': 235,
#  'decontamination': 236,
#  'missable': 237,
#  'stuccoed': 238,
#  'sharecropper': 239,
#  'fect': 240,
#  'kadeem': 241,
#  'onde': 242,
#  'spotters': 243,
#  'crisis': 244,
#  'bogeymen': 245,
#  'ochoa': 246,
#  'flamengo': 247,
#  'caste': 248,
#  'drivel': 249,
#  'tete': 250,
#  'endearment': 251,
#  'amigos': 252,
#  'bansihed': 253,
#  'kruis': 254,
#  'drexler': 255,
#  'somewhere': 256,
#  'newest': 257,
#  'ironists': 258,
#  'campground': 259,
#  'tum': 260,
#  'disslikes': 261,
#  'projected': 262,
#  'wegener': 263,
#  'bullish': 264,
#  'ostensibly': 265,
#  'factotum': 266,
#  'mapple': 267,
#  'vanderbeek': 268,
#  'polishes': 269,
#  'fiendishly': 270,
#  'intel': 271,
#  'prescriptions': 272,
#  'specialized': 273,
#  'saga': 274,
#  'allegiance': 275,
#  'nimble': 276,
#  'wrenchingly': 277,
#  'poche': 278,
#  'possibilities': 279,
#  'sans': 280,
#  'pedagogue': 281,
#  'poorness': 282,
#  'autocracy': 283,
#  'anxiously': 284,
#  'boundries': 285,
#  'ended': 286,
#  'chainsaw': 287,
#  'chalked': 288,
#  'sums': 289,
#  'unneccesary': 290,
#  'trainspotter': 291,
#  'shamefully': 292,
#  'triangulated': 293,
#  'steven': 294,
#  'enforced': 295,
#  'showerman': 296,
#  'schnappmann': 297,
#  'prohibitions': 298,
#  'remit': 299,
#  'pinet': 300,
#  'ueto': 301,
#  'abhors': 302,
#  'seller': 303,
#  'nous': 304,
#  'punctuations': 305,
#  'chubbiness': 306,
#  'boen': 307,
#  'strive': 308,
#  'bo': 309,
#  'proposals': 310,
#  'slapsticks': 311,
#  'anorectic': 312,
#  'aspiring': 313,
#  'hilliard': 314,
#  'elizbethan': 315,
#  'kohara': 316,
#  'spotting': 317,
#  'gruenberg': 318,
#  'gahannah': 319,
#  'hymer': 320,
#  'stonking': 321,
#  'hoo': 322,
#  'canister': 323,
#  'peng': 324,
#  'superannuated': 325,
#  'birds': 326,
#  'pauses': 327,
#  'lamb': 328,
#  'overacted': 329,
#  'register': 330,
#  'hedonist': 331,
#  'nog': 332,
#  'sidekick': 333,
#  'pudney': 334,
#  'intrigued': 335,
#  'intimidated': 336,
#  'disconnect': 337,
#  'harrison': 338,
#  'epitomised': 339,
#  'worlde': 340,
#  'indulgently': 341,
#  'voltage': 342,
#  'javo': 343,
#  'boerner': 344,
#  'freiberger': 345,
#  'catgirls': 346,
#  'dispenses': 347,
#  'ajeeb': 348,
#  'aboutan': 349,
#  'eileen': 350,
#  'berk': 351,
#  'jianna': 352,
#  'understandable': 353,
#  'tantalised': 354,
#  'gubbarre': 355,
#  'acquire': 356,
#  'newtypes': 357,
#  'madhvi': 358,
#  'wallow': 359,
#  'excavations': 360,
#  'galland': 361,
#  'postpone': 362,
#  'invoke': 363,
#  'sigfried': 364,
#  'recut': 365,
#  'sullied': 366,
#  'telford': 367,
#  'belafonte': 368,
#  'spawns': 369,
#  'hamminess': 370,
#  'mechapiloting': 371,
#  'haiku': 372,
#  'furnished': 373,
#  'shos': 374,
#  'tennapel': 375,
#  'heats': 376,
#  'priorities': 377,
#  'repellent': 378,
#  'vestment': 379,
#  'liz': 380,
#  'propeller': 381,
#  'elvis': 382,
#  'playing': 383,
#  'ultramagnetic': 384,
#  'reverie': 385,
#  'punkah': 386,
#  'issuey': 387,
#  'plankton': 388,
#  'irreverent': 389,
#  'scottish': 390,
#  'strobe': 391,
#  'sockets': 392,
#  'pence': 393,
#  'caudillos': 394,
#  'embedded': 395,
#  'extended': 396,
#  'slumming': 397,
#  'replacated': 398,
#  'allthis': 399,
#  'bleak': 400,
#  'rubinek': 401,
#  'reflected': 402,
#  'blainsworth': 403,
#  'moments': 404,
#  'accommodations': 405,
#  'nearly': 406,
#  'saucepan': 407,
#  'haywood': 408,
#  'conceded': 409,
#  'cbbc': 410,
#  'license': 411,
#  'spout': 412,
#  'uncertainties': 413,
#  'ferguson': 414,
#  'mischievous': 415,
#  'uncaring': 416,
#  'thereabouts': 417,
#  'plexiglas': 418,
#  'cholate': 419,
#  'magtena': 420,
#  'laggard': 421,
#  'egotistical': 422,
#  'crumpled': 423,
#  'kilpatrick': 424,
#  'glamor': 425,
#  'naif': 426,
#  'shankar': 427,
#  'batboy': 428,
#  'mailing': 429,
#  'tamerlane': 430,
#  'slitheen': 431,
#  'pardesi': 432,
#  'coincidental': 433,
#  'massude': 434,
#  'scenes': 435,
#  'renovating': 436,
#  'tsu': 437,
#  'academe': 438,
#  'asthetics': 439,
#  'divoff': 440,
#  'troy': 441,
#  'nambla': 442,
#  'sanest': 443,
#  'walker': 444,
#  'maliciousness': 445,
#  'budjet': 446,
#  'truculent': 447,
#  'disorganized': 448,
#  'nightie': 449,
#  'erica': 450,
#  'impounding': 451,
#  'pataki': 452,
#  'gentile': 453,
#  'cruelty': 454,
#  'hallan': 455,
#  'sprightly': 456,
#  'bloopers': 457,
#  'forme': 458,
#  'trunk': 459,
#  'renounced': 460,
#  'house': 461,
#  'menges': 462,
#  'ripper': 463,
#  'tadpole': 464,
#  'paulson': 465,
#  'colonialist': 466,
#  'chief': 467,
#  'briny': 468,
#  'chagos': 469,
#  'rhythmically': 470,
#  'moralistic': 471,
#  'cost': 472,
#  'zsigmond': 473,
#  'placeholder': 474,
#  'vcd': 475,
#  'anuses': 476,
#  'wuss': 477,
#  'firebombs': 478,
#  'obligates': 479,
#  'heezy': 480,
#  'natascha': 481,
#  'uncharted': 482,
#  'streetwalker': 483,
#  'ravenna': 484,
#  'espinazo': 485,
#  'predicaments': 486,
#  'kassie': 487,
#  'stealthily': 488,
#  'networking': 489,
#  'lesotho': 490,
#  'zach': 491,
#  'cena': 492,
#  'chair': 493,
#  'albacore': 494,
#  'dislodge': 495,
#  'shoudln': 496,
#  'oddness': 497,
#  'boles': 498,
#  'ifying': 499,
#  'mest': 500,
#  'baltar': 501,
#  'objectors': 502,
#  'organisations': 503,
#  'alexia': 504,
#  'urbanized': 505,
#  'compactor': 506,
#  'referred': 507,
#  'hubris': 508,
#  'musters': 509,
#  'malfatti': 510,
#  'salaryman': 511,
#  'belittled': 512,
#  'mofu': 513,
#  'rivette': 514,
#  'ohgo': 515,
#  'lark': 516,
#  'zapdos': 517,
#  'audition': 518,
#  'nanni': 519,
#  'emmannuelle': 520,
#  'irrespective': 521,
#  'unearthing': 522,
#  'gawdawful': 523,
#  'teases': 524,
#  'catalua': 525,
#  'tazmainian': 526,
#  'gunslinger': 527,
#  'undergo': 528,
#  'californian': 529,
#  'fran': 530,
#  'helmut': 531,
#  'vooren': 532,
#  'hiring': 533,
#  'ivans': 534,
#  'tually': 535,
#  'incest': 536,
#  'sofiko': 537,
#  'ruper': 538,
#  'schoedsack': 539,
#  'bushwacker': 540,
#  'bambaiya': 541,
#  'imprisonment': 542,
#  'melonie': 543,
#  'intellects': 544,
#  'lopardi': 545,
#  'cocoons': 546,
#  'companion': 547,
#  'unmanageable': 548,
#  'pedicab': 549,
#  'aunties': 550,
#  'trickle': 551,
#  'hereabouts': 552,
#  'batrice': 553,
#  'shrinks': 554,
#  'playthings': 555,
#  'linenone': 556,
#  'vandeuvres': 557,
#  'sequence': 558,
#  'ono': 559,
#  'highjinks': 560,
#  'pad': 561,
#  'elves': 562,
#  'dreufuss': 563,
#  'shouldn': 564,
#  'han': 565,
#  'elvidge': 566,
#  'scars': 567,
#  'ifpi': 568,
#  'pack': 569,
#  'balaguero': 570,
#  'lieutenant': 571,
#  'combusts': 572,
#  'blissful': 573,
#  'hobbiton': 574,
#  'iffr': 575,
#  'pakage': 576,
#  'concocting': 577,
#  'turtle': 578,
#  'insubordinate': 579,
#  'fruedian': 580,
#  'roughest': 581,
#  'saw': 582,
#  'romantic': 583,
#  'mausoleum': 584,
#  'acknowledged': 585,
#  'hotch': 586,
#  'chabert': 587,
#  'specif': 588,
#  'linoleum': 589,
#  'ti': 590,
#  'klasky': 591,
#  'populations': 592,
#  'goner': 593,
#  'jackie': 594,
#  'audiocassette': 595,
#  'krook': 596,
#  'glisten': 597,
#  'fluffy': 598,
#  'schmitz': 599,
#  'dawkins': 600,
#  'scarwid': 601,
#  'behaviours': 602,
#  'step': 603,
#  'caribbean': 604,
#  'wisbech': 605,
#  'mei': 606,
#  'dubiety': 607,
#  'unkwown': 608,
#  'narsimha': 609,
#  'coordinated': 610,
#  'woeful': 611,
#  'propels': 612,
#  'mourned': 613,
#  'konvitz': 614,
#  'bukowski': 615,
#  'helumis': 616,
#  'disappointments': 617,
#  'advisedly': 618,
#  'absurdness': 619,
#  'strang': 620,
#  'tovarish': 621,
#  'alleys': 622,
#  'shipyards': 623,
#  'wassell': 624,
#  'majestically': 625,
#  'glimmers': 626,
#  'skeins': 627,
#  'kana': 628,
#  'aapkey': 629,
#  'contaminate': 630,
#  'giudizio': 631,
#  'tarzan': 632,
#  'feffer': 633,
#  'abounding': 634,
#  'hairdressing': 635,
#  'manouvres': 636,
#  'skivvies': 637,
#  'breslin': 638,
#  'twentynine': 639,
#  'princesses': 640,
#  'seiryuu': 641,
#  'enjoyably': 642,
#  'budge': 643,
#  'tarot': 644,
#  'judith': 645,
#  'spacecrafts': 646,
#  'funfare': 647,
#  'shatners': 648,
#  'c': 649,
#  'flats': 650,
#  'kalama': 651,
#  'digressing': 652,
#  'experimentalism': 653,
#  'carvalho': 654,
#  'chill': 655,
#  'magnetic': 656,
#  'revels': 657,
#  'freshest': 658,
#  'ggauff': 659,
#  'byrnes': 660,
#  'illicit': 661,
#  'camaraderie': 662,
#  'reduction': 663,
#  'alma': 664,
#  'dominic': 665,
#  'columned': 666,
#  'volptuous': 667,
#  'ayat': 668,
#  'cruelness': 669,
#  'lexus': 670,
#  'karo': 671,
#  'heavenlier': 672,
#  'screenwriters': 673,
#  'harboring': 674,
#  'craparama': 675,
#  'under': 676,
#  'kitumura': 677,
#  'alraira': 678,
#  'pleasence': 679,
#  'allergy': 680,
#  'extroverts': 681,
#  'porfirio': 682,
#  'tsh': 683,
#  'pentimento': 684,
#  'hards': 685,
#  'duchess': 686,
#  'locken': 687,
#  'hercule': 688,
#  'overridden': 689,
#  'allotting': 690,
#  'kirtland': 691,
#  'depended': 692,
#  'scudded': 693,
#  'scarfing': 694,
#  'restriction': 695,
#  'beasts': 696,
#  'unbelievable': 697,
#  'payoffs': 698,
#  'civilizational': 699,
#  'flubbed': 700,
#  'unanimousness': 701,
#  'bulgari': 702,
#  'ungraced': 703,
#  'flores': 704,
#  'konec': 705,
#  'bolliwood': 706,
#  'absurdity': 707,
#  'retains': 708,
#  'vertically': 709,
#  'jaekel': 710,
#  'partners': 711,
#  'gwyenth': 712,
#  'leland': 713,
#  'triggering': 714,
#  'verdict': 715,
#  'devoting': 716,
#  'arriving': 717,
#  'leadenly': 718,
#  'austreim': 719,
#  'marshland': 720,
#  'kneed': 721,
#  'remix': 722,
#  'lauded': 723,
#  'atmospheres': 724,
#  'forewarning': 725,
#  'macbeal': 726,
#  'ronnie': 727,
#  'overindulgence': 728,
#  'ney': 729,
#  'comteg': 730,
#  'lens': 731,
#  'moorish': 732,
#  'prescient': 733,
#  'land': 734,
#  'tosha': 735,
#  'delusive': 736,
#  'mnage': 737,
#  'montesi': 738,
#  'plowed': 739,
#  'screwier': 740,
#  'sorceries': 741,
#  'romancing': 742,
#  'politico': 743,
#  'swingblade': 744,
#  'civilizations': 745,
#  'champ': 746,
#  'nikolaidis': 747,
#  'blinkered': 748,
#  'romantick': 749,
#  'update': 750,
#  'logon': 751,
#  'estefan': 752,
#  'dolled': 753,
#  'kin': 754,
#  'montagne': 755,
#  'guddi': 756,
#  'stever': 757,
#  'agreed': 758,
#  'shaq': 759,
#  'roux': 760,
#  'beaty': 761,
#  'tenement': 762,
#  'inconsistencies': 763,
#  'giuseppe': 764,
#  'quit': 765,
#  'struggled': 766,
#  'imaginings': 767,
#  'freedoms': 768,
#  'cutthroat': 769,
#  'forging': 770,
#  'ratbatspidercrab': 771,
#  'tossers': 772,
#  'popinjays': 773,
#  'weepers': 774,
#  'pleasants': 775,
#  'shrimp': 776,
#  'topping': 777,
#  'tvnz': 778,
#  'galles': 779,
#  'daneliucs': 780,
#  'commuter': 781,
#  'malik': 782,
#  'hilter': 783,
#  'reputations': 784,
#  'unmystied': 785,
#  'ruhr': 786,
#  'boomerang': 787,
#  'sacrament': 788,
#  'unmasking': 789,
#  'cayenne': 790,
#  'turn': 791,
#  'backdoor': 792,
#  'dumland': 793,
#  'aviv': 794,
#  'fabulously': 795,
#  'blonds': 796,
#  'despondent': 797,
#  'salubrious': 798,
#  'sleeved': 799,
#  'inherits': 800,
#  'exclude': 801,
#  'collectivity': 802,
#  'liable': 803,
#  'estevo': 804,
#  'thomerson': 805,
#  'prettily': 806,
#  'decoration': 807,
#  'facially': 808,
#  'yokels': 809,
#  'buffaloes': 810,
#  'zack': 811,
#  'frazzlingly': 812,
#  'ineffably': 813,
#  'rationalism': 814,
#  'dirtmaster': 815,
#  'kitchen': 816,
#  'disgraceful': 817,
#  'worth': 818,
#  'leonov': 819,
#  'susanah': 820,
#  'borderline': 821,
#  'bhag': 822,
#  'debases': 823,
#  'dalmation': 824,
#  'snippy': 825,
#  'shusuke': 826,
#  'nonproportionally': 827,
#  'straights': 828,
#  'weakest': 829,
#  'teething': 830,
#  'explained': 831,
#  'farreley': 832,
#  'critters': 833,
#  'hiroshima': 834,
#  'extracting': 835,
#  'brody': 836,
#  'sumer': 837,
#  'cuter': 838,
#  'requiem': 839,
#  'monotheist': 840,
#  'regents': 841,
#  'trapero': 842,
#  'sopping': 843,
#  'admiral': 844,
#  'undulating': 845,
#  'atreides': 846,
#  'prompter': 847,
#  'rigshospitalet': 848,
#  'thunderous': 849,
#  'hatched': 850,
#  'wallowing': 851,
#  'montel': 852,
#  'tibbets': 853,
#  'flatman': 854,
#  'transvestive': 855,
#  'pazienza': 856,
#  'trivialize': 857,
#  'sparkling': 858,
#  'beguiling': 859,
#  'roddenberry': 860,
#  'psychedelic': 861,
#  'magnus': 862,
#  'crystalline': 863,
#  'sixty': 864,
#  'shekhar': 865,
#  'sabbath': 866,
#  'juttering': 867,
#  'longshormen': 868,
#  'mannerism': 869,
#  'suess': 870,
#  'princesse': 871,
#  'preamble': 872,
#  'cornfields': 873,
#  'longed': 874,
#  'giver': 875,
#  'nami': 876,
#  'kinekor': 877,
#  'internationally': 878,
#  'obscurities': 879,
#  'chamionship': 880,
#  'brommel': 881,
#  'outnumber': 882,
#  'dinheiro': 883,
#  'learns': 884,
#  'malleable': 885,
#  'seater': 886,
#  'summers': 887,
#  'pleads': 888,
#  'boopous': 889,
#  'eliniak': 890,
#  'cof': 891,
#  'vacuum': 892,
#  'zarustica': 893,
#  'guiding': 894,
#  'marathi': 895,
#  'sayles': 896,
#  'seaquest': 897,
#  'catastrophic': 898,
#  'chalonte': 899,
#  'hallelujah': 900,
#  'overrate': 901,
#  'buh': 902,
#  'fiving': 903,
#  'kasbah': 904,
#  'pharisees': 905,
#  'mainstays': 906,
#  'romerfeller': 907,
#  'politique': 908,
#  'sized': 909,
#  'pictorial': 910,
#  'relish': 911,
#  'seemore': 912,
#  'flutes': 913,
#  'arvide': 914,
#  'bg': 915,
#  'hallorann': 916,
#  'disdains': 917,
#  'travelodge': 918,
#  'transfuse': 919,
#  'clone': 920,
#  'jakub': 921,
#  'gomer': 922,
#  'carolingians': 923,
#  'charactistical': 924,
#  'goth': 925,
#  'sloppiest': 926,
#  'diminutive': 927,
#  'cameoing': 928,
#  'pupi': 929,
#  'blazkowicz': 930,
#  'bleating': 931,
#  'kish': 932,
#  'humored': 933,
#  'acceded': 934,
#  'mortgan': 935,
#  'knin': 936,
#  'gigli': 937,
#  'lansbury': 938,
#  'hellbreed': 939,
#  'shelby': 940,
#  'moshkov': 941,
#  'outcry': 942,
#  'lobbies': 943,
#  'vaulting': 944,
#  'synthesiser': 945,
#  'thin': 946,
#  'brumes': 947,
#  'chuckleheads': 948,
#  'dalek': 949,
#  'fez': 950,
#  'playboys': 951,
#  'dinasty': 952,
#  'everybodies': 953,
#  'baiscally': 954,
#  'goddamned': 955,
#  'jolts': 956,
#  'solids': 957,
#  'conversed': 958,
#  'inaccuracy': 959,
#  'loader': 960,
#  'raccoons': 961,
#  'repulsed': 962,
#  'vhala': 963,
#  'rosa': 964,
#  'gwyenths': 965,
#  'swearing': 966,
#  'sprinkles': 967,
#  'rehearse': 968,
#  'foal': 969,
#  'calhern': 970,
#  'enthusast': 971,
#  'daisens': 972,
#  'gradualism': 973,
#  'secretary': 974,
#  'egg': 975,
#  'suba': 976,
#  'benumbed': 977,
#  'kristoferson': 978,
#  'wore': 979,
#  'vato': 980,
#  'covers': 981,
#  'fogelman': 982,
#  'dullllllllllll': 983,
#  'ykai': 984,
#  'judged': 985,
#  'zeppo': 986,
#  'yung': 987,
#  'adhura': 988,
#  'csi': 989,
#  'rhinestones': 990,
#  'horticulturalist': 991,
#  'weezing': 992,
#  'cohesive': 993,
#  'ang': 994,
#  'creaming': 995,
#  'segregating': 996,
#  'abraham': 997,
#  'obituaries': 998,
#  'watsoever': 999,
#  ...}

# %%
# Function to vectorize each review (set 1 at all words in the review to 1, 0 otherwise)

def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] = 1

# Function to convert label to 1 or 0

def get_target_for_label(label):
    if(label == 'POSITIVE'):
        return 1
    else:
        return 0

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[ 1.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# ## Reduce noise in the data

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cbecc20a-d0fe-4a06-b7d6-43e21edfecc9">Loading BokehJS ...</span>
#     </div>

# %%
# Most of the words, for example: 'a', 'an', 'the', etc., repeat in both positive and negative reviews
# We need to only consider the words that have higher co-relation to their labels
# Following is the co-relation graph of each word with respect to its label
# A large number of words near the mean of the below distribution are ambiguous, we don't really need to consider them

hist, edges = np.histogram(list(map(lambda x: x[1], pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan, wheel_zoom, reset, save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="61f9442f-1d67-4d8a-9f50-66f9b4595e74"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("61f9442f-1d67-4d8a-9f50-66f9b4595e74").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("61f9442f-1d67-4d8a-9f50-66f9b4595e74");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '61f9442f-1d67-4d8a-9f50-66f9b4595e74' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6749dc8a-14ee-4c3c-978f-84e556f97798":{"roots":{"references":[{"attributes":{},"id":"c630fe5e-3f13-4787-a883-9ee607d9b436","type":"BasicTicker"},{"attributes":{},"id":"850c6649-2ad6-4752-9b86-37b5193648fb","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"afbf7b73-e9c0-4a51-8199-44e5a1ef347e","type":"ColumnDataSource"},{"attributes":{},"id":"69da8203-ce64-4caa-81c5-3b900619dff3","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"10f37e61-a936-47d1-bf1e-173619cae354","subtype":"Figure","type":"Plot"},"ticker":{"id":"850c6649-2ad6-4752-9b86-37b5193648fb","type":"BasicTicker"}},"id":"95075a55-432a-4ba7-b311-71c755c4ab8a","type":"Grid"},{"attributes":{"plot":{"id":"10f37e61-a936-47d1-bf1e-173619cae354","subtype":"Figure","type":"Plot"}},"id":"94de2cc3-14c9-4a9d-a12e-91dbe023938c","type":"PanTool"},{"attributes":{"plot":{"id":"10f37e61-a936-47d1-bf1e-173619cae354","subtype":"Figure","type":"Plot"}},"id":"060595cf-6169-4eb9-8169-fd9431c39f90","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"08ddabea-4924-4450-baa9-51b60eab6450","type":"LinearAxis"}],"left":[{"id":"95647fa5-4784-4c1c-8bde-e744c1b8406f","type":"LinearAxis"}],"renderers":[{"id":"08ddabea-4924-4450-baa9-51b60eab6450","type":"LinearAxis"},{"id":"6771253f-55c5-4d99-9353-76039857ee94","type":"Grid"},{"id":"95647fa5-4784-4c1c-8bde-e744c1b8406f","type":"LinearAxis"},{"id":"95075a55-432a-4ba7-b311-71c755c4ab8a","type":"Grid"},{"id":"3f966f4c-ef7b-4cda-9f40-cba39f5f7ada","type":"GlyphRenderer"}],"title":{"id":"cc798da3-357e-42f7-b63c-b21f29b1e60a","type":"Title"},"tool_events":{"id":"0b8570e9-f00e-4f63-8b36-495056e69693","type":"ToolEvents"},"toolbar":{"id":"f596c169-d9e2-4169-bc81-9279e0a93a83","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"38bca67b-6848-4047-86a9-a9cd5763bc16","type":"DataRange1d"},"y_range":{"id":"8b0a3086-2f34-4b02-b9c4-9ab946c32de4","type":"DataRange1d"}},"id":"10f37e61-a936-47d1-bf1e-173619cae354","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1182ac83-6232-4ead-8e6f-f56c9df732f4","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Word Positive/Negative Affinity Distribution"},"id":"cc798da3-357e-42f7-b63c-b21f29b1e60a","type":"Title"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"f0a6c811-a765-4054-ac00-31045fca12b5","type":"Quad"},{"attributes":{"plot":{"id":"10f37e61-a936-47d1-bf1e-173619cae354","subtype":"Figure","type":"Plot"}},"id":"e552a9f9-aa27-4eda-b8b7-ae1ce10bbecb","type":"ResetTool"},{"attributes":{"callback":null},"id":"38bca67b-6848-4047-86a9-a9cd5763bc16","type":"DataRange1d"},{"attributes":{"plot":{"id":"10f37e61-a936-47d1-bf1e-173619cae354","subtype":"Figure","type":"Plot"}},"id":"8f4f1bf8-9821-454a-8202-fda6a4f5117d","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"94de2cc3-14c9-4a9d-a12e-91dbe023938c","type":"PanTool"},{"id":"060595cf-6169-4eb9-8169-fd9431c39f90","type":"WheelZoomTool"},{"id":"e552a9f9-aa27-4eda-b8b7-ae1ce10bbecb","type":"ResetTool"},{"id":"8f4f1bf8-9821-454a-8202-fda6a4f5117d","type":"SaveTool"}]},"id":"f596c169-d9e2-4169-bc81-9279e0a93a83","type":"Toolbar"},{"attributes":{"formatter":{"id":"69da8203-ce64-4caa-81c5-3b900619dff3","type":"BasicTickFormatter"},"plot":{"id":"10f37e61-a936-47d1-bf1e-173619cae354","subtype":"Figure","type":"Plot"},"ticker":{"id":"c630fe5e-3f13-4787-a883-9ee607d9b436","type":"BasicTicker"}},"id":"08ddabea-4924-4450-baa9-51b60eab6450","type":"LinearAxis"},{"attributes":{"data_source":{"id":"afbf7b73-e9c0-4a51-8199-44e5a1ef347e","type":"ColumnDataSource"},"glyph":{"id" ...

# %%
# Let's look at one more distribution to really assure that

word_frequency = Counter()

for word, cnt in total_counts.most_common():
    word_frequency[cnt] += 1

hist, edges = np.histogram(list(map(lambda x: x[1], word_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan, wheel_zoom, reset, save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# As you can see from the below plot, there are few term that dominate the corpus. 
# To get better results, we have to eliminate the words that are most frequent and less frequent.
# Let's do that next
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bd09be1a-b62e-4cdf-94a0-782965ee68d3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bd09be1a-b62e-4cdf-94a0-782965ee68d3").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd09be1a-b62e-4cdf-94a0-782965ee68d3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd09be1a-b62e-4cdf-94a0-782965ee68d3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a97b649d-60d3-442d-9742-43b1319839ee":{"roots":{"references":[{"attributes":{"callback":null},"id":"93d72730-b0ba-4816-84b0-00a363467a3d","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"182515be-0d20-45ca-8f11-6619baed13cb","type":"PanTool"},{"id":"8e5ceae1-6ed2-4ee3-b5fd-00a0bed238d4","type":"WheelZoomTool"},{"id":"f57ea3d0-91a0-4bab-9e07-3af9cb366688","type":"ResetTool"},{"id":"8f3bbaa1-e3c4-415f-a32f-0ef76ba257ed","type":"SaveTool"}]},"id":"f9129379-31f9-4acc-b33c-1bae3efa3769","type":"Toolbar"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"76cfed5a-bd56-41ef-b739-da07547beb56","type":"Quad"},{"attributes":{"below":[{"id":"cd471dc4-20cc-4e6a-a2e7-27c7aa87f34d","type":"LinearAxis"}],"left":[{"id":"7b75ef23-bde3-42f4-b103-575a6d86d86e","type":"LinearAxis"}],"renderers":[{"id":"cd471dc4-20cc-4e6a-a2e7-27c7aa87f34d","type":"LinearAxis"},{"id":"e501e2de-89da-4de5-b90f-7a49d062fc10","type":"Grid"},{"id":"7b75ef23-bde3-42f4-b103-575a6d86d86e","type":"LinearAxis"},{"id":"213cfedf-27c4-421a-acb7-49819a0a1a3e","type":"Grid"},{"id":"0644652b-76b9-49e2-8a7f-92102e5583fb","type":"GlyphRenderer"}],"title":{"id":"4f3cf5d4-5ace-49f1-a2b2-7ae070736bf1","type":"Title"},"tool_events":{"id":"2241b1ef-47a4-48b4-b7a5-1d86aa72c9e4","type":"ToolEvents"},"toolbar":{"id":"f9129379-31f9-4acc-b33c-1bae3efa3769","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"93d72730-b0ba-4816-84b0-00a363467a3d","type":"DataRange1d"},"y_range":{"id":"9fee2ef4-2a7b-4827-a32b-56b921b91670","type":"DataRange1d"}},"id":"5a81cbde-5609-4fc9-bb67-648ff7dd5842","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"The frequency distribution of the words in our corpus"},"id":"4f3cf5d4-5ace-49f1-a2b2-7ae070736bf1","type":"Title"},{"attributes":{},"id":"a09b0897-c3d7-406f-a2d4-52e9021cfa3c","type":"BasicTickFormatter"},{"attributes":{},"id":"2cbcbc3c-8ae2-4d6d-8964-6fd2ee8b0424","type":"BasicTicker"},{"attributes":{"data_source":{"id":"d2b3b933-4bbc-411e-8ff6-017ede7d00a1","type":"ColumnDataSource"},"glyph":{"id":"76cfed5a-bd56-41ef-b739-da07547beb56","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"7490c7ff-5508-4748-8c74-a589f5c636c3","type":"Quad"},"selection_glyph":null},"id":"0644652b-76b9-49e2-8a7f-92102e5583fb","type":"GlyphRenderer"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"7490c7ff-5508-4748-8c74-a589f5c636c3","type":"Quad"},{"attributes":{"dimension":1,"plot":{"id":"5a81cbde-5609-4fc9-bb67-648ff7dd5842","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5b6364f-9945-497b-8510-c20fc5dd52b7","type":"BasicTicker"}},"id":"213cfedf-27c4-421a-acb7-49819a0a1a3e","type":"Grid"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"d2b3b933-4bbc-411e-8ff6-017ede7d00a1","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5a81cbde-5609-4fc9-bb67-648ff7dd5842","subtype":"Figure","type":"Plot"}},"id":"182515be-0d20-45ca-8f11-6619baed13cb","type":"PanTool"},{"attributes":{},"id":"2241b1ef-47a4-48b4-b7a5-1d86aa72c9e4","type":"ToolEvents"},{"attributes":{},"id":"e5b6364f-9945-497b-8510-c20fc5dd52b7","type":"BasicTicker"},{"attributes":{"callback":null},"id":"9fee2ef4-2a7b-4827-a32b-56b921b91670","type":"DataRange1d"},{"attributes":{"plot":{"id":"5a81cbde-5609-4fc9-bb67-648ff7dd5842","subtype":"Figure","type":"Plot"}},"id":"f57ea3d0-91a0-4bab-9e07-3af9cb366688","type":"ResetTool"},{"attributes":{"formatter":{"i ...

# %%
# consider only words that are important as discussed before

review_vocab = set()
min_count = 20
polarity_cutoff = 0.5

for review in reviews:
    for word in review.split(" "):
        if(total_counts[word] > min_count):
            if(word in pos_neg_ratios.keys()):
                if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
                    review_vocab.add(word)
            else:
                review_vocab.add(word)
review_vocab = list(review_vocab)
review_vocab
# Out:
# ['approval',
#  'targeted',
#  'influence',
#  'idiocy',
#  'dyer',
#  'televised',
#  'gillian',
#  'othello',
#  'sarcasm',
#  'smallest',
#  'jameson',
#  'astounding',
#  'diner',
#  'oberon',
#  'jannings',
#  'torso',
#  'rubber',
#  'fading',
#  'abysmal',
#  'literate',
#  'kolchak',
#  'utah',
#  'mommy',
#  'management',
#  'gimmicks',
#  'foreground',
#  'gameplay',
#  'neighbors',
#  'havoc',
#  'franchise',
#  'professionals',
#  'characterized',
#  'edwards',
#  'settling',
#  'facade',
#  'conflicted',
#  'teddy',
#  'ingrid',
#  'infectious',
#  'cher',
#  'preaching',
#  'farewell',
#  'dealt',
#  'throwing',
#  'slug',
#  'devious',
#  'howard',
#  'apparently',
#  'sexes',
#  'custody',
#  'screaming',
#  'surrender',
#  'fatale',
#  'seducing',
#  'plausibility',
#  'pasted',
#  'delight',
#  'convoluted',
#  'natasha',
#  'historian',
#  'triple',
#  'connelly',
#  'excuse',
#  'billing',
#  'sideways',
#  'horns',
#  'charming',
#  'comedienne',
#  'cowboy',
#  'rourke',
#  'december',
#  'imagines',
#  'beth',
#  'transcends',
#  'girlfight',
#  'forest',
#  'woke',
#  'equation',
#  'menu',
#  'exudes',
#  'curtis',
#  'camping',
#  'desolate',
#  'displaying',
#  'karl',
#  'confirm',
#  'obscene',
#  'wouldn',
#  'corporations',
#  'tearjerker',
#  'essay',
#  'outlaw',
#  'thirdly',
#  'consequence',
#  'wildlife',
#  'edith',
#  'lo',
#  'buttgereit',
#  'pretensions',
#  'solidly',
#  'someone',
#  'testimony',
#  'percent',
#  'ilk',
#  'touching',
#  'chunk',
#  'stiles',
#  'orwell',
#  'pub',
#  'tease',
#  'roof',
#  'overshadowed',
#  'altered',
#  'tin',
#  'akshay',
#  'drivel',
#  'valerie',
#  'confederate',
#  'indifference',
#  'inheritance',
#  'supporter',
#  'deathtrap',
#  'engages',
#  'dexter',
#  'shameful',
#  'somewhere',
#  'newest',
#  'heir',
#  'projected',
#  'miners',
#  'ostensibly',
#  'iran',
#  'saga',
#  'grudge',
#  'sans',
#  'gritty',
#  'prequel',
#  'abby',
#  'harvard',
#  'chainsaw',
#  'togar',
#  'sums',
#  'heroic',
#  'cushing',
#  'sunday',
#  'operations',
#  'uneducated',
#  'horrendous',
#  'seller',
#  'monica',
#  'strive',
#  'bo',
#  'finishes',
#  'hilliard',
#  'trey',
#  'intellectually',
#  'strained',
#  'prop',
#  'horrors',
#  'champion',
#  'pang',
#  'trippy',
#  'pauses',
#  'lamb',
#  'register',
#  'gratuitous',
#  'luis',
#  'permanent',
#  'hackneyed',
#  'automatic',
#  'raid',
#  'activist',
#  'footlight',
#  'milland',
#  'eileen',
#  'smell',
#  'acquire',
#  'palatable',
#  'lumiere',
#  'tomatoes',
#  'absurdly',
#  'tying',
#  'extravagant',
#  'nc',
#  'pioneer',
#  'dodgy',
#  'vanishes',
#  'rings',
#  'rave',
#  'mechanics',
#  'repellent',
#  'sheridan',
#  'liz',
#  'elvis',
#  'snail',
#  'ongoing',
#  'irreverent',
#  'acceptance',
#  'gusto',
#  'submission',
#  'bleak',
#  'reflected',
#  'interpretations',
#  'awkwardly',
#  'flops',
#  'inventive',
#  'granddaughter',
#  'humiliating',
#  'argued',
#  'license',
#  'thinner',
#  'mischievous',
#  'pupils',
#  'egotistical',
#  'dreary',
#  'young',
#  'troy',
#  'afloat',
#  'mann',
#  'truths',
#  'erica',
#  'hacking',
#  'trunk',
#  'revolt',
#  'ripper',
#  'poorest',
#  'calm',
#  'bombing',
#  'warn',
#  'sr',
#  'always',
#  'eddie',
#  'clueless',
#  'bothered',
#  'andrew',
#  'criticism',
#  'aaron',
#  'rory',
#  'cena',
#  'zach',
#  'transforming',
#  'caf',
#  'abu',
#  'referred',
#  'demonic',
#  'toni',
#  'sorcerer',
#  'zealand',
#  'shining',
#  'hiring',
#  'astonishingly',
#  'importance',
#  'incest',
#  'irrational',
#  'teeth',
#  'pretentious',
#  'casablanca',
#  'berenger',
#  'loneliness',
#  'forgiveness',
#  'additions',
#  'backwoods',
#  'pakistan',
#  'pad',
#  'han',
#  'scars',
#  'lieutenant',
#  'wallach',
#  'wrought',
#  'turtle',
#  'romantic',
#  'acknowledged',
#  'discount',
#  'realistic',
#  'soccer',
#  'jackie',
#  'wb',
#  'krishna',
#  'fluffy',
#  'fifties',
#  'caribbean',
#  'mph',
#  'stoned',
#  'strangelove',
#  'progressive',
#  'woeful',
#  'favourite',
#  'disappointments',
#  'picker',
#  'bout',
#  'diaries',
#  'rescued',
#  'melinda',
#  'nyc',
#  'layers',
#  'roaming',
#  'hawks',
#  'igor',
#  'oft',
#  'tarzan',
#  'remakes',
#  'pen',
#  'enjoyably',
#  'definitely',
#  'cabaret',
#  'dopey',
#  'invested',
#  'hanzo',
#  'sammo',
#  'thing',
#  'dignified',
#  'magnetic',
#  'slaughterhouse',
#  'communities',
#  'dominic',
#  'declare',
#  'robby',
#  'screenwriters',
#  'suv',
#  'streets',
#  'duchess',
#  'monkey',
#  'untalented',
#  'emma',
#  'morse',
#  'empire',
#  'failed',
#  'palm',
#  'cypher',
#  'waters',
#  'coroner',
#  'unbelievable',
#  'retains',
#  'partners',
#  'startling',
#  'demons',
#  'empty',
#  'choreographer',
#  'restricted',
#  'emerged',
#  'entries',
#  'weissmuller',
#  'spacek',
#  'lens',
#  'darkest',
#  'weirdness',
#  'earning',
#  'childhood',
#  'scenarios',
#  'invading',
#  'sum',
#  'palace',
#  'belgian',
#  'agreed',
#  'shaq',
#  'pastor',
#  'inconsistencies',
#  'barbara',
#  'gabe',
#  'struggled',
#  'mastery',
#  'elliot',
#  'malik',
#  'breathe',
#  'breathtaking',
#  'timid',
#  'gigantic',
#  'sweaty',
#  'redgrave',
#  'aviv',
#  'pornography',
#  'gaining',
#  'submarine',
#  'decoration',
#  'bonham',
#  'midget',
#  'irene',
#  'zack',
#  'attacking',
#  'inn',
#  'appallingly',
#  'clair',
#  'disgraceful',
#  'mcadams',
#  'borderline',
#  'relied',
#  'styled',
#  'dances',
#  'explained',
#  'suspended',
#  'robs',
#  'assets',
#  'brody',
#  'gleefully',
#  'noisy',
#  'ted',
#  'permanently',
#  'bernard',
#  'karate',
#  'jovi',
#  'feared',
#  'sparkling',
#  'label',
#  'psychedelic',
#  'sixty',
#  'arcs',
#  'shekhar',
#  'eerily',
#  'adrenaline',
#  'buffy',
#  'pleasant',
#  'divided',
#  'learns',
#  'electricity',
#  'professionalism',
#  'balloon',
#  'guiding',
#  'finishing',
#  'arbitrary',
#  'dangerfield',
#  'dillinger',
#  'redeemed',
#  'lambert',
#  'sized',
#  'relish',
#  'relieved',
#  'preference',
#  'clone',
#  'youth',
#  'ages',
#  'goth',
#  'sammy',
#  'nothing',
#  'lansbury',
#  'kline',
#  'pia',
#  'slob',
#  'babysitter',
#  'boorman',
#  'thin',
#  'elderly',
#  'fez',
#  'collapse',
#  'duchovny',
#  'peet',
#  'scarce',
#  'franchot',
#  'swearing',
#  'wraps',
#  'ecstasy',
#  'producers',
#  'parking',
#  'downer',
#  'secretary',
#  'egg',
#  'degrading',
#  'blair',
#  'complains',
#  'covers',
#  'idealism',
#  'csi',
#  'widowed',
#  'distinctive',
#  'cohesive',
#  'ang',
#  'abraham',
#  'heartbreaking',
#  'speechless',
#  'hitch',
#  'maniacal',
#  'rebels',
#  'stares',
#  'mist',
#  'exhibits',
#  'rugged',
#  'groove',
#  'sharp',
#  'received',
#  'concrete',
#  'achieves',
#  'epps',
#  'italians',
#  'harmony',
#  'rko',
#  'foremost',
#  'utilized',
#  'formulaic',
#  'bagdad',
#  'skeleton',
#  'knightly',
#  'lorna',
#  'errol',
#  'davis',
#  'paula',
#  'flair',
#  'ta',
#  'geeky',
#  'dwarfs',
#  'lung',
#  'dialog',
#  'sultry',
#  'clause',
#  'thug',
#  'brendan',
#  'vogue',
#  'recovered',
#  'dye',
#  'starlet',
#  'relaxed',
#  'hanson',
#  'nacho',
#  'lovingly',
#  'filter',
#  'takashi',
#  'threesome',
#  'droll',
#  'fry',
#  'bread',
#  'louque',
#  'expense',
#  'mins',
#  'drink',
#  'stereotyping',
#  'cheer',
#  'fahey',
#  'landlady',
#  'retreat',
#  'rural',
#  'conquest',
#  'lousy',
#  'mastermind',
#  'doe',
#  'legion',
#  'sensibility',
#  'holes',
#  'merry',
#  'proportions',
#  'offenders',
#  'lin',
#  'cement',
#  'renegade',
#  'kiefer',
#  'lt',
#  'pakistani',
#  'engagement',
#  'policies',
#  'protection',
#  'feeble',
#  'attracts',
#  'depiction',
#  'beans',
#  'nifty',
#  'batwoman',
#  'expand',
#  'sky',
#  'marching',
#  'yuzna',
#  'bouncing',
#  'capsule',
#  'eugene',
#  'celebrate',
#  'owl',
#  'association',
#  'grandeur',
#  'perfection',
#  'mixes',
#  'singles',
#  'observing',
#  'meanders',
#  'skies',
#  'wood',
#  'orphan',
#  'backgrounds',
#  'metropolis',
#  'superiors',
#  'singleton',
#  'carmen',
#  'brilliance',
#  'plants',
#  'unbeknownst',
#  'bachchan',
#  'dual',
#  'drowning',
#  'adultery',
#  'darth',
#  'advances',
#  'captures',
#  'unfolding',
#  'devito',
#  'vaudeville',
#  'hagar',
#  'stewart',
#  'luke',
#  'spliced',
#  'beginnings',
#  'obsessive',
#  'sarno',
#  'ala',
#  'guevara',
#  'cohen',
#  'bittersweet',
#  'po',
#  'magic',
#  'scarecrows',
#  'services',
#  'charges',
#  'venezuelan',
#  'pray',
#  'dunne',
#  'ajay',
#  'lumet',
#  'agatha',
#  'drained',
#  'labour',
#  'formal',
#  'upbeat',
#  'mcgregor',
#  'triumphs',
#  'hispanic',
#  'oblivion',
#  'father',
#  'lengths',
#  'tainted',
#  'benoit',
#  'lent',
#  'serviceable',
#  'sho',
#  'sisters',
#  'frenchman',
#  'abe',
#  'insulted',
#  'lecherous',
#  'bowie',
#  'welch',
#  'underlying',
#  'mamet',
#  'soo',
#  'masterful',
#  'celebration',
#  'smarmy',
#  'extensive',
#  'shrill',
#  'ft',
#  'zoo',
#  'jock',
#  'unfinished',
#  'rudy',
#  'muscle',
#  'tracey',
#  'hysterically',
#  'moses',
#  'photograph',
#  'yacht',
#  'cassavetes',
#  'roeg',
#  'contemplate',
#  'inducing',
#  'vomit',
#  'manson',
#  'clerk',
#  'sidney',
#  'embarrassed',
#  'dreamed',
#  'hanna',
#  'documents',
#  'glimpses',
#  'silverman',
#  'beforehand',
#  'crushing',
#  'gandalf',
#  'shannon',
#  'rao',
#  'brothel',
#  'martino',
#  'morton',
#  'warhols',
#  'panned',
#  'whip',
#  'meatball',
#  'edits',
#  'loretta',
#  'surprises',
#  'uneasy',
#  'cleaned',
#  'gifted',
#  'disgrace',
#  'pokemon',
#  'notch',
#  'leaps',
#  'farther',
#  'shapes',
#  'tricks',
#  'careless',
#  'jurassic',
#  'pillow',
#  'shearer',
#  'flute',
#  'joseph',
#  'inserted',
#  'replay',
#  'priyanka',
#  'grating',
#  'vanilla',
#  'utterly',
#  'witty',
#  'surprisingly',
#  'scenic',
#  'voight',
#  'omega',
#  'existential',
#  'rogers',
#  'anchorman',
#  'phones',
#  'myra',
#  'christianity',
#  'jewel',
#  'sharply',
#  'ashamed',
#  'bore',
#  'disappearing',
#  'dodge',
#  'amos',
#  'liv',
#  'texture',
#  'moviegoers',
#  'distraught',
#  'matched',
#  'radioactive',
#  'memories',
#  'interactions',
#  'sarne',
#  'wtc',
#  'no',
#  'glow',
#  'varied',
#  'grind',
#  'goodies',
#  'grocery',
#  'inexplicably',
#  'trappings',
#  'atmospheric',
#  'praising',
#  'thereby',
#  'policemen',
#  'minutes',
#  'mismatched',
#  'applegate',
#  'cape',
#  'looses',
#  'ka',
#  'mouse',
#  'becky',
#  'cracker',
#  'creeps',
#  'outrage',
#  'brady',
#  'arise',
#  'browsing',
#  'flee',
#  'pertwee',
#  'juvenile',
#  'stale',
#  'cringe',
#  'drugged',
#  'quasi',
#  'jerky',
#  'sweet',
#  'heroin',
#  'shocker',
#  'wyatt',
#  'appreciated',
#  'writings',
#  'teamed',
#  'hallucination',
#  'moto',
#  'romy',
#  'tack',
#  'sabu',
#  'enjoy',
#  'hack',
#  'distorted',
#  'practicing',
#  'resourceful',
#  'understatement',
#  'intentions',
#  'hk',
#  'graduation',
#  'janet',
#  'jaffar',
#  'applied',
#  'impressively',
#  'subjected',
#  'worrying',
#  'ripe',
#  'cathy',
#  'fund',
#  'hunger',
#  'stages',
#  'tattoo',
#  'privileged',
#  'rival',
#  'mannered',
#  'tyrone',
#  'complaints',
#  'mae',
#  'eustache',
#  'lemon',
#  'enterprise',
#  'ludicrously',
#  'monstrosity',
#  'overseas',
#  'colours',
#  'fooled',
#  'awaited',
#  'hyper',
#  'shows',
#  'glances',
#  'fur',
#  'lightweight',
#  'incessant',
#  'christy',
#  'palma',
#  'weekend',
#  'mandatory',
#  'dreamworks',
#  'gwynne',
#  'vows',
#  'famed',
#  'concentrates',
#  'heroines',
#  'entertainer',
#  'mack',
#  'veronica',
#  'nada',
#  'explores',
#  'india',
#  'coherence',
#  'captivating',
#  'pretense',
#  'carr',
#  'cavalry',
#  'indy',
#  'nutshell',
#  'whoopi',
#  'rudd',
#  'leo',
#  'artemisia',
#  'gomez',
#  'hung',
#  'infected',
#  'grease',
#  'pee',
#  'rangers',
#  'seduce',
#  'carlo',
#  'lacking',
#  'share',
#  'ledger',
#  'inhabitants',
#  'staircase',
#  'rewarding',
#  'reprise',
#  'omar',
#  'farting',
#  'rambling',
#  'sabrina',
#  'regain',
#  'mock',
#  'inaccuracies',
#  'premise',
#  'winded',
#  'hugo',
#  'predicament',
#  'waterfront',
#  'cheats',
#  'sharif',
#  'saif',
#  'survival',
#  'caprica',
#  'district',
#  'charlie',
#  'dub',
#  'concert',
#  'snappy',
#  'carole',
#  'amnesia',
#  'patriotism',
#  'controls',
#  'fondly',
#  'composition',
#  'trainer',
#  'gonna',
#  'fiery',
#  'ally',
#  'blob',
#  'nolte',
#  'horrible',
#  'herein',
#  'responds',
#  'congress',
#  'mutual',
#  'gestures',
#  'stratten',
#  'emotionally',
#  'crisp',
#  'synchronized',
#  'confirmed',
#  'carlyle',
#  'balancing',
#  'angela',
#  'envelope',
#  'bonanza',
#  'colonial',
#  'intimacy',
#  'bumps',
#  'forwards',
#  'fling',
#  'deus',
#  'insignificant',
#  'terminal',
#  'arrogance',
#  'experts',
#  'framework',
#  'greed',
#  'compelling',
#  'pit',
#  'boils',
#  'sheet',
#  'overcome',
#  'outer',
#  'tackles',
#  'alley',
#  'dismal',
#  'heyday',
#  'lerner',
#  'offs',
#  'dani',
#  'knoxville',
#  'disappointment',
#  'dealing',
#  'runtime',
#  'coherent',
#  'millard',
#  'deepest',
#  'converted',
#  'kei',
#  'whining',
#  'jack',
#  'throats',
#  'eyre',
#  'solo',
#  'ceiling',
#  'disbelief',
#  'hostile',
#  'cillian',
#  'missions',
#  'ditto',
#  'stevenson',
#  'unrealistic',
#  'indirectly',
#  'classy',
#  'reese',
#  'galactica',
#  'clouds',
#  'hometown',
#  'embark',
#  'todd',
#  'farcical',
#  'boards',
#  'aime',
#  'malta',
#  'sessions',
#  'shamelessly',
#  'heavens',
#  'documentaries',
#  'torch',
#  'gifts',
#  'clan',
#  'puerile',
#  'believers',
#  'albeit',
#  'saint',
#  'promotion',
#  'tempted',
#  'metaphysical',
#  'monstrous',
#  'prefers',
#  'stalwart',
#  'instrumental',
#  'stalker',
#  'harry',
#  'scarlett',
#  'affluent',
#  'drone',
#  'expressed',
#  'articulate',
#  'joanna',
#  'germany',
#  'dam',
#  'brash',
#  ...]

# %%
# Each review is vectorized to a vector of length = length of revized vocabulary
# Find the index of each word in the vector

word2index = {}
for i, word in enumerate(review_vocab):
    word2index[word] = i
word2index
# Out:
# {'approval': 0,
#  'targeted': 1,
#  'influence': 2,
#  'idiocy': 3,
#  'dyer': 4,
#  'televised': 5,
#  'gillian': 6,
#  'othello': 7,
#  'sarcasm': 8,
#  'smallest': 9,
#  'jameson': 10,
#  'astounding': 11,
#  'diner': 12,
#  'oberon': 13,
#  'jannings': 14,
#  'torso': 15,
#  'rubber': 16,
#  'fading': 17,
#  'abysmal': 18,
#  'literate': 19,
#  'kolchak': 20,
#  'utah': 21,
#  'mommy': 22,
#  'management': 23,
#  'gimmicks': 24,
#  'foreground': 25,
#  'gameplay': 26,
#  'neighbors': 27,
#  'havoc': 28,
#  'franchise': 29,
#  'professionals': 30,
#  'characterized': 31,
#  'edwards': 32,
#  'settling': 33,
#  'facade': 34,
#  'conflicted': 35,
#  'teddy': 36,
#  'ingrid': 37,
#  'infectious': 38,
#  'cher': 39,
#  'preaching': 40,
#  'farewell': 41,
#  'dealt': 42,
#  'throwing': 43,
#  'slug': 44,
#  'devious': 45,
#  'howard': 46,
#  'apparently': 47,
#  'sexes': 48,
#  'custody': 49,
#  'screaming': 50,
#  'surrender': 51,
#  'fatale': 52,
#  'seducing': 53,
#  'plausibility': 54,
#  'pasted': 55,
#  'delight': 56,
#  'convoluted': 57,
#  'natasha': 58,
#  'historian': 59,
#  'triple': 60,
#  'connelly': 61,
#  'excuse': 62,
#  'billing': 63,
#  'sideways': 64,
#  'horns': 65,
#  'charming': 66,
#  'comedienne': 67,
#  'cowboy': 68,
#  'rourke': 69,
#  'december': 70,
#  'imagines': 71,
#  'beth': 72,
#  'transcends': 73,
#  'girlfight': 74,
#  'forest': 75,
#  'woke': 76,
#  'equation': 77,
#  'menu': 78,
#  'exudes': 79,
#  'curtis': 80,
#  'camping': 81,
#  'desolate': 82,
#  'displaying': 83,
#  'karl': 84,
#  'confirm': 85,
#  'obscene': 86,
#  'wouldn': 87,
#  'corporations': 88,
#  'tearjerker': 89,
#  'essay': 90,
#  'outlaw': 91,
#  'thirdly': 92,
#  'consequence': 93,
#  'wildlife': 94,
#  'edith': 95,
#  'lo': 96,
#  'buttgereit': 97,
#  'pretensions': 98,
#  'solidly': 99,
#  'someone': 100,
#  'testimony': 101,
#  'percent': 102,
#  'ilk': 103,
#  'touching': 104,
#  'chunk': 105,
#  'stiles': 106,
#  'orwell': 107,
#  'pub': 108,
#  'tease': 109,
#  'roof': 110,
#  'overshadowed': 111,
#  'altered': 112,
#  'tin': 113,
#  'akshay': 114,
#  'drivel': 115,
#  'valerie': 116,
#  'confederate': 117,
#  'indifference': 118,
#  'inheritance': 119,
#  'supporter': 120,
#  'deathtrap': 121,
#  'engages': 122,
#  'dexter': 123,
#  'shameful': 124,
#  'somewhere': 125,
#  'newest': 126,
#  'heir': 127,
#  'projected': 128,
#  'miners': 129,
#  'ostensibly': 130,
#  'iran': 131,
#  'saga': 132,
#  'grudge': 133,
#  'sans': 134,
#  'gritty': 135,
#  'prequel': 136,
#  'abby': 137,
#  'harvard': 138,
#  'chainsaw': 139,
#  'togar': 140,
#  'sums': 141,
#  'heroic': 142,
#  'cushing': 143,
#  'sunday': 144,
#  'operations': 145,
#  'uneducated': 146,
#  'horrendous': 147,
#  'seller': 148,
#  'monica': 149,
#  'strive': 150,
#  'bo': 151,
#  'finishes': 152,
#  'hilliard': 153,
#  'trey': 154,
#  'intellectually': 155,
#  'strained': 156,
#  'prop': 157,
#  'horrors': 158,
#  'champion': 159,
#  'pang': 160,
#  'trippy': 161,
#  'pauses': 162,
#  'lamb': 163,
#  'register': 164,
#  'gratuitous': 165,
#  'luis': 166,
#  'permanent': 167,
#  'hackneyed': 168,
#  'automatic': 169,
#  'raid': 170,
#  'activist': 171,
#  'footlight': 172,
#  'milland': 173,
#  'eileen': 174,
#  'smell': 175,
#  'acquire': 176,
#  'palatable': 177,
#  'lumiere': 178,
#  'tomatoes': 179,
#  'absurdly': 180,
#  'tying': 181,
#  'extravagant': 182,
#  'nc': 183,
#  'pioneer': 184,
#  'dodgy': 185,
#  'vanishes': 186,
#  'rings': 187,
#  'rave': 188,
#  'mechanics': 189,
#  'repellent': 190,
#  'sheridan': 191,
#  'liz': 192,
#  'elvis': 193,
#  'snail': 194,
#  'ongoing': 195,
#  'irreverent': 196,
#  'acceptance': 197,
#  'gusto': 198,
#  'submission': 199,
#  'bleak': 200,
#  'reflected': 201,
#  'interpretations': 202,
#  'awkwardly': 203,
#  'flops': 204,
#  'inventive': 205,
#  'granddaughter': 206,
#  'humiliating': 207,
#  'argued': 208,
#  'license': 209,
#  'thinner': 210,
#  'mischievous': 211,
#  'pupils': 212,
#  'egotistical': 213,
#  'dreary': 214,
#  'young': 215,
#  'troy': 216,
#  'afloat': 217,
#  'mann': 218,
#  'truths': 219,
#  'erica': 220,
#  'hacking': 221,
#  'trunk': 222,
#  'revolt': 223,
#  'ripper': 224,
#  'poorest': 225,
#  'calm': 226,
#  'bombing': 227,
#  'warn': 228,
#  'sr': 229,
#  'always': 230,
#  'eddie': 231,
#  'clueless': 232,
#  'bothered': 233,
#  'andrew': 234,
#  'criticism': 235,
#  'aaron': 236,
#  'rory': 237,
#  'cena': 238,
#  'zach': 239,
#  'transforming': 240,
#  'caf': 241,
#  'abu': 242,
#  'referred': 243,
#  'demonic': 244,
#  'toni': 245,
#  'sorcerer': 246,
#  'zealand': 247,
#  'shining': 248,
#  'hiring': 249,
#  'astonishingly': 250,
#  'importance': 251,
#  'incest': 252,
#  'irrational': 253,
#  'teeth': 254,
#  'pretentious': 255,
#  'casablanca': 256,
#  'berenger': 257,
#  'loneliness': 258,
#  'forgiveness': 259,
#  'additions': 260,
#  'backwoods': 261,
#  'pakistan': 262,
#  'pad': 263,
#  'han': 264,
#  'scars': 265,
#  'lieutenant': 266,
#  'wallach': 267,
#  'wrought': 268,
#  'turtle': 269,
#  'romantic': 270,
#  'acknowledged': 271,
#  'discount': 272,
#  'realistic': 273,
#  'soccer': 274,
#  'jackie': 275,
#  'wb': 276,
#  'krishna': 277,
#  'fluffy': 278,
#  'fifties': 279,
#  'caribbean': 280,
#  'mph': 281,
#  'stoned': 282,
#  'strangelove': 283,
#  'progressive': 284,
#  'woeful': 285,
#  'favourite': 286,
#  'disappointments': 287,
#  'picker': 288,
#  'bout': 289,
#  'diaries': 290,
#  'rescued': 291,
#  'melinda': 292,
#  'nyc': 293,
#  'layers': 294,
#  'roaming': 295,
#  'hawks': 296,
#  'igor': 297,
#  'oft': 298,
#  'tarzan': 299,
#  'remakes': 300,
#  'pen': 301,
#  'enjoyably': 302,
#  'definitely': 303,
#  'cabaret': 304,
#  'dopey': 305,
#  'invested': 306,
#  'hanzo': 307,
#  'sammo': 308,
#  'thing': 309,
#  'dignified': 310,
#  'magnetic': 311,
#  'slaughterhouse': 312,
#  'communities': 313,
#  'dominic': 314,
#  'declare': 315,
#  'robby': 316,
#  'screenwriters': 317,
#  'suv': 318,
#  'streets': 319,
#  'duchess': 320,
#  'monkey': 321,
#  'untalented': 322,
#  'emma': 323,
#  'morse': 324,
#  'empire': 325,
#  'failed': 326,
#  'palm': 327,
#  'cypher': 328,
#  'waters': 329,
#  'coroner': 330,
#  'unbelievable': 331,
#  'retains': 332,
#  'partners': 333,
#  'startling': 334,
#  'demons': 335,
#  'empty': 336,
#  'choreographer': 337,
#  'restricted': 338,
#  'emerged': 339,
#  'entries': 340,
#  'weissmuller': 341,
#  'spacek': 342,
#  'lens': 343,
#  'darkest': 344,
#  'weirdness': 345,
#  'earning': 346,
#  'childhood': 347,
#  'scenarios': 348,
#  'invading': 349,
#  'sum': 350,
#  'palace': 351,
#  'belgian': 352,
#  'agreed': 353,
#  'shaq': 354,
#  'pastor': 355,
#  'inconsistencies': 356,
#  'barbara': 357,
#  'gabe': 358,
#  'struggled': 359,
#  'mastery': 360,
#  'elliot': 361,
#  'malik': 362,
#  'breathe': 363,
#  'breathtaking': 364,
#  'timid': 365,
#  'gigantic': 366,
#  'sweaty': 367,
#  'redgrave': 368,
#  'aviv': 369,
#  'pornography': 370,
#  'gaining': 371,
#  'submarine': 372,
#  'decoration': 373,
#  'bonham': 374,
#  'midget': 375,
#  'irene': 376,
#  'zack': 377,
#  'attacking': 378,
#  'inn': 379,
#  'appallingly': 380,
#  'clair': 381,
#  'disgraceful': 382,
#  'mcadams': 383,
#  'borderline': 384,
#  'relied': 385,
#  'styled': 386,
#  'dances': 387,
#  'explained': 388,
#  'suspended': 389,
#  'robs': 390,
#  'assets': 391,
#  'brody': 392,
#  'gleefully': 393,
#  'noisy': 394,
#  'ted': 395,
#  'permanently': 396,
#  'bernard': 397,
#  'karate': 398,
#  'jovi': 399,
#  'feared': 400,
#  'sparkling': 401,
#  'label': 402,
#  'psychedelic': 403,
#  'sixty': 404,
#  'arcs': 405,
#  'shekhar': 406,
#  'eerily': 407,
#  'adrenaline': 408,
#  'buffy': 409,
#  'pleasant': 410,
#  'divided': 411,
#  'learns': 412,
#  'electricity': 413,
#  'professionalism': 414,
#  'balloon': 415,
#  'guiding': 416,
#  'finishing': 417,
#  'arbitrary': 418,
#  'dangerfield': 419,
#  'dillinger': 420,
#  'redeemed': 421,
#  'lambert': 422,
#  'sized': 423,
#  'relish': 424,
#  'relieved': 425,
#  'preference': 426,
#  'clone': 427,
#  'youth': 428,
#  'ages': 429,
#  'goth': 430,
#  'sammy': 431,
#  'nothing': 432,
#  'lansbury': 433,
#  'kline': 434,
#  'pia': 435,
#  'slob': 436,
#  'babysitter': 437,
#  'boorman': 438,
#  'thin': 439,
#  'elderly': 440,
#  'fez': 441,
#  'collapse': 442,
#  'duchovny': 443,
#  'peet': 444,
#  'scarce': 445,
#  'franchot': 446,
#  'swearing': 447,
#  'wraps': 448,
#  'ecstasy': 449,
#  'producers': 450,
#  'parking': 451,
#  'downer': 452,
#  'secretary': 453,
#  'egg': 454,
#  'degrading': 455,
#  'blair': 456,
#  'complains': 457,
#  'covers': 458,
#  'idealism': 459,
#  'csi': 460,
#  'widowed': 461,
#  'distinctive': 462,
#  'cohesive': 463,
#  'ang': 464,
#  'abraham': 465,
#  'heartbreaking': 466,
#  'speechless': 467,
#  'hitch': 468,
#  'maniacal': 469,
#  'rebels': 470,
#  'stares': 471,
#  'mist': 472,
#  'exhibits': 473,
#  'rugged': 474,
#  'groove': 475,
#  'sharp': 476,
#  'received': 477,
#  'concrete': 478,
#  'achieves': 479,
#  'epps': 480,
#  'italians': 481,
#  'harmony': 482,
#  'rko': 483,
#  'foremost': 484,
#  'utilized': 485,
#  'formulaic': 486,
#  'bagdad': 487,
#  'skeleton': 488,
#  'knightly': 489,
#  'lorna': 490,
#  'errol': 491,
#  'davis': 492,
#  'paula': 493,
#  'flair': 494,
#  'ta': 495,
#  'geeky': 496,
#  'dwarfs': 497,
#  'lung': 498,
#  'dialog': 499,
#  'sultry': 500,
#  'clause': 501,
#  'thug': 502,
#  'brendan': 503,
#  'vogue': 504,
#  'recovered': 505,
#  'dye': 506,
#  'starlet': 507,
#  'relaxed': 508,
#  'hanson': 509,
#  'nacho': 510,
#  'lovingly': 511,
#  'filter': 512,
#  'takashi': 513,
#  'threesome': 514,
#  'droll': 515,
#  'fry': 516,
#  'bread': 517,
#  'louque': 518,
#  'expense': 519,
#  'mins': 520,
#  'drink': 521,
#  'stereotyping': 522,
#  'cheer': 523,
#  'fahey': 524,
#  'landlady': 525,
#  'retreat': 526,
#  'rural': 527,
#  'conquest': 528,
#  'lousy': 529,
#  'mastermind': 530,
#  'doe': 531,
#  'legion': 532,
#  'sensibility': 533,
#  'holes': 534,
#  'merry': 535,
#  'proportions': 536,
#  'offenders': 537,
#  'lin': 538,
#  'cement': 539,
#  'renegade': 540,
#  'kiefer': 541,
#  'lt': 542,
#  'pakistani': 543,
#  'engagement': 544,
#  'policies': 545,
#  'protection': 546,
#  'feeble': 547,
#  'attracts': 548,
#  'depiction': 549,
#  'beans': 550,
#  'nifty': 551,
#  'batwoman': 552,
#  'expand': 553,
#  'sky': 554,
#  'marching': 555,
#  'yuzna': 556,
#  'bouncing': 557,
#  'capsule': 558,
#  'eugene': 559,
#  'celebrate': 560,
#  'owl': 561,
#  'association': 562,
#  'grandeur': 563,
#  'perfection': 564,
#  'mixes': 565,
#  'singles': 566,
#  'observing': 567,
#  'meanders': 568,
#  'skies': 569,
#  'wood': 570,
#  'orphan': 571,
#  'backgrounds': 572,
#  'metropolis': 573,
#  'superiors': 574,
#  'singleton': 575,
#  'carmen': 576,
#  'brilliance': 577,
#  'plants': 578,
#  'unbeknownst': 579,
#  'bachchan': 580,
#  'dual': 581,
#  'drowning': 582,
#  'adultery': 583,
#  'darth': 584,
#  'advances': 585,
#  'captures': 586,
#  'unfolding': 587,
#  'devito': 588,
#  'vaudeville': 589,
#  'hagar': 590,
#  'stewart': 591,
#  'luke': 592,
#  'spliced': 593,
#  'beginnings': 594,
#  'obsessive': 595,
#  'sarno': 596,
#  'ala': 597,
#  'guevara': 598,
#  'cohen': 599,
#  'bittersweet': 600,
#  'po': 601,
#  'magic': 602,
#  'scarecrows': 603,
#  'services': 604,
#  'charges': 605,
#  'venezuelan': 606,
#  'pray': 607,
#  'dunne': 608,
#  'ajay': 609,
#  'lumet': 610,
#  'agatha': 611,
#  'drained': 612,
#  'labour': 613,
#  'formal': 614,
#  'upbeat': 615,
#  'mcgregor': 616,
#  'triumphs': 617,
#  'hispanic': 618,
#  'oblivion': 619,
#  'father': 620,
#  'lengths': 621,
#  'tainted': 622,
#  'benoit': 623,
#  'lent': 624,
#  'serviceable': 625,
#  'sho': 626,
#  'sisters': 627,
#  'frenchman': 628,
#  'abe': 629,
#  'insulted': 630,
#  'lecherous': 631,
#  'bowie': 632,
#  'welch': 633,
#  'underlying': 634,
#  'mamet': 635,
#  'soo': 636,
#  'masterful': 637,
#  'celebration': 638,
#  'smarmy': 639,
#  'extensive': 640,
#  'shrill': 641,
#  'ft': 642,
#  'zoo': 643,
#  'jock': 644,
#  'unfinished': 645,
#  'rudy': 646,
#  'muscle': 647,
#  'tracey': 648,
#  'hysterically': 649,
#  'moses': 650,
#  'photograph': 651,
#  'yacht': 652,
#  'cassavetes': 653,
#  'roeg': 654,
#  'contemplate': 655,
#  'inducing': 656,
#  'vomit': 657,
#  'manson': 658,
#  'clerk': 659,
#  'sidney': 660,
#  'embarrassed': 661,
#  'dreamed': 662,
#  'hanna': 663,
#  'documents': 664,
#  'glimpses': 665,
#  'silverman': 666,
#  'beforehand': 667,
#  'crushing': 668,
#  'gandalf': 669,
#  'shannon': 670,
#  'rao': 671,
#  'brothel': 672,
#  'martino': 673,
#  'morton': 674,
#  'warhols': 675,
#  'panned': 676,
#  'whip': 677,
#  'meatball': 678,
#  'edits': 679,
#  'loretta': 680,
#  'surprises': 681,
#  'uneasy': 682,
#  'cleaned': 683,
#  'gifted': 684,
#  'disgrace': 685,
#  'pokemon': 686,
#  'notch': 687,
#  'leaps': 688,
#  'farther': 689,
#  'shapes': 690,
#  'tricks': 691,
#  'careless': 692,
#  'jurassic': 693,
#  'pillow': 694,
#  'shearer': 695,
#  'flute': 696,
#  'joseph': 697,
#  'inserted': 698,
#  'replay': 699,
#  'priyanka': 700,
#  'grating': 701,
#  'vanilla': 702,
#  'utterly': 703,
#  'witty': 704,
#  'surprisingly': 705,
#  'scenic': 706,
#  'voight': 707,
#  'omega': 708,
#  'existential': 709,
#  'rogers': 710,
#  'anchorman': 711,
#  'phones': 712,
#  'myra': 713,
#  'christianity': 714,
#  'jewel': 715,
#  'sharply': 716,
#  'ashamed': 717,
#  'bore': 718,
#  'disappearing': 719,
#  'dodge': 720,
#  'amos': 721,
#  'liv': 722,
#  'texture': 723,
#  'moviegoers': 724,
#  'distraught': 725,
#  'matched': 726,
#  'radioactive': 727,
#  'memories': 728,
#  'interactions': 729,
#  'sarne': 730,
#  'wtc': 731,
#  'no': 732,
#  'glow': 733,
#  'varied': 734,
#  'grind': 735,
#  'goodies': 736,
#  'grocery': 737,
#  'inexplicably': 738,
#  'trappings': 739,
#  'atmospheric': 740,
#  'praising': 741,
#  'thereby': 742,
#  'policemen': 743,
#  'minutes': 744,
#  'mismatched': 745,
#  'applegate': 746,
#  'cape': 747,
#  'looses': 748,
#  'ka': 749,
#  'mouse': 750,
#  'becky': 751,
#  'cracker': 752,
#  'creeps': 753,
#  'outrage': 754,
#  'brady': 755,
#  'arise': 756,
#  'browsing': 757,
#  'flee': 758,
#  'pertwee': 759,
#  'juvenile': 760,
#  'stale': 761,
#  'cringe': 762,
#  'drugged': 763,
#  'quasi': 764,
#  'jerky': 765,
#  'sweet': 766,
#  'heroin': 767,
#  'shocker': 768,
#  'wyatt': 769,
#  'appreciated': 770,
#  'writings': 771,
#  'teamed': 772,
#  'hallucination': 773,
#  'moto': 774,
#  'romy': 775,
#  'tack': 776,
#  'sabu': 777,
#  'enjoy': 778,
#  'hack': 779,
#  'distorted': 780,
#  'practicing': 781,
#  'resourceful': 782,
#  'understatement': 783,
#  'intentions': 784,
#  'hk': 785,
#  'graduation': 786,
#  'janet': 787,
#  'jaffar': 788,
#  'applied': 789,
#  'impressively': 790,
#  'subjected': 791,
#  'worrying': 792,
#  'ripe': 793,
#  'cathy': 794,
#  'fund': 795,
#  'hunger': 796,
#  'stages': 797,
#  'tattoo': 798,
#  'privileged': 799,
#  'rival': 800,
#  'mannered': 801,
#  'tyrone': 802,
#  'complaints': 803,
#  'mae': 804,
#  'eustache': 805,
#  'lemon': 806,
#  'enterprise': 807,
#  'ludicrously': 808,
#  'monstrosity': 809,
#  'overseas': 810,
#  'colours': 811,
#  'fooled': 812,
#  'awaited': 813,
#  'hyper': 814,
#  'shows': 815,
#  'glances': 816,
#  'fur': 817,
#  'lightweight': 818,
#  'incessant': 819,
#  'christy': 820,
#  'palma': 821,
#  'weekend': 822,
#  'mandatory': 823,
#  'dreamworks': 824,
#  'gwynne': 825,
#  'vows': 826,
#  'famed': 827,
#  'concentrates': 828,
#  'heroines': 829,
#  'entertainer': 830,
#  'mack': 831,
#  'veronica': 832,
#  'nada': 833,
#  'explores': 834,
#  'india': 835,
#  'coherence': 836,
#  'captivating': 837,
#  'pretense': 838,
#  'carr': 839,
#  'cavalry': 840,
#  'indy': 841,
#  'nutshell': 842,
#  'whoopi': 843,
#  'rudd': 844,
#  'leo': 845,
#  'artemisia': 846,
#  'gomez': 847,
#  'hung': 848,
#  'infected': 849,
#  'grease': 850,
#  'pee': 851,
#  'rangers': 852,
#  'seduce': 853,
#  'carlo': 854,
#  'lacking': 855,
#  'share': 856,
#  'ledger': 857,
#  'inhabitants': 858,
#  'staircase': 859,
#  'rewarding': 860,
#  'reprise': 861,
#  'omar': 862,
#  'farting': 863,
#  'rambling': 864,
#  'sabrina': 865,
#  'regain': 866,
#  'mock': 867,
#  'inaccuracies': 868,
#  'premise': 869,
#  'winded': 870,
#  'hugo': 871,
#  'predicament': 872,
#  'waterfront': 873,
#  'cheats': 874,
#  'sharif': 875,
#  'saif': 876,
#  'survival': 877,
#  'caprica': 878,
#  'district': 879,
#  'charlie': 880,
#  'dub': 881,
#  'concert': 882,
#  'snappy': 883,
#  'carole': 884,
#  'amnesia': 885,
#  'patriotism': 886,
#  'controls': 887,
#  'fondly': 888,
#  'composition': 889,
#  'trainer': 890,
#  'gonna': 891,
#  'fiery': 892,
#  'ally': 893,
#  'blob': 894,
#  'nolte': 895,
#  'horrible': 896,
#  'herein': 897,
#  'responds': 898,
#  'congress': 899,
#  'mutual': 900,
#  'gestures': 901,
#  'stratten': 902,
#  'emotionally': 903,
#  'crisp': 904,
#  'synchronized': 905,
#  'confirmed': 906,
#  'carlyle': 907,
#  'balancing': 908,
#  'angela': 909,
#  'envelope': 910,
#  'bonanza': 911,
#  'colonial': 912,
#  'intimacy': 913,
#  'bumps': 914,
#  'forwards': 915,
#  'fling': 916,
#  'deus': 917,
#  'insignificant': 918,
#  'terminal': 919,
#  'arrogance': 920,
#  'experts': 921,
#  'framework': 922,
#  'greed': 923,
#  'compelling': 924,
#  'pit': 925,
#  'boils': 926,
#  'sheet': 927,
#  'overcome': 928,
#  'outer': 929,
#  'tackles': 930,
#  'alley': 931,
#  'dismal': 932,
#  'heyday': 933,
#  'lerner': 934,
#  'offs': 935,
#  'dani': 936,
#  'knoxville': 937,
#  'disappointment': 938,
#  'dealing': 939,
#  'runtime': 940,
#  'coherent': 941,
#  'millard': 942,
#  'deepest': 943,
#  'converted': 944,
#  'kei': 945,
#  'whining': 946,
#  'jack': 947,
#  'throats': 948,
#  'eyre': 949,
#  'solo': 950,
#  'ceiling': 951,
#  'disbelief': 952,
#  'hostile': 953,
#  'cillian': 954,
#  'missions': 955,
#  'ditto': 956,
#  'stevenson': 957,
#  'unrealistic': 958,
#  'indirectly': 959,
#  'classy': 960,
#  'reese': 961,
#  'galactica': 962,
#  'clouds': 963,
#  'hometown': 964,
#  'embark': 965,
#  'todd': 966,
#  'farcical': 967,
#  'boards': 968,
#  'aime': 969,
#  'malta': 970,
#  'sessions': 971,
#  'shamelessly': 972,
#  'heavens': 973,
#  'documentaries': 974,
#  'torch': 975,
#  'gifts': 976,
#  'clan': 977,
#  'puerile': 978,
#  'believers': 979,
#  'albeit': 980,
#  'saint': 981,
#  'promotion': 982,
#  'tempted': 983,
#  'metaphysical': 984,
#  'monstrous': 985,
#  'prefers': 986,
#  'stalwart': 987,
#  'instrumental': 988,
#  'stalker': 989,
#  'harry': 990,
#  'scarlett': 991,
#  'affluent': 992,
#  'drone': 993,
#  'expressed': 994,
#  'articulate': 995,
#  'joanna': 996,
#  'germany': 997,
#  'dam': 998,
#  'brash': 999,
#  ...}

# %% [markdown]
# ## Building a Neural Network (Incorporating previously discussed concepts)

# %%
from IPython.display import Image
Image(filename='sentiment_network_sparse.png')

# %%
import time
import sys
import numpy as np

class SentimentNetwork:
    def __init__(self, reviews,labels,min_count = 10,polarity_cutoff = 0.1,hidden_nodes = 10, learning_rate = 0.1):
       
        np.random.seed(1)
    
        self.pre_process_data(reviews, polarity_cutoff, min_count)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self,reviews, polarity_cutoff,min_count):
        
        positive_counts = Counter()
        negative_counts = Counter()
        total_counts = Counter()

        for i in range(len(reviews)):
            if(labels[i] == 'POSITIVE'):
                for word in reviews[i].split(" "):
                    positive_counts[word] += 1
                    total_counts[word] += 1
            else:
                for word in reviews[i].split(" "):
                    negative_counts[word] += 1
                    total_counts[word] += 1

        pos_neg_ratios = Counter()

        for term,cnt in list(total_counts.most_common()):
            if(cnt >= 50):
                pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
                pos_neg_ratios[term] = pos_neg_ratio

        for word,ratio in pos_neg_ratios.most_common():
            if(ratio > 1):
                pos_neg_ratios[word] = np.log(ratio)
            else:
                pos_neg_ratios[word] = -np.log((1 / (ratio + 0.01)))
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                if(total_counts[word] > min_count):
                    if(word in pos_neg_ratios.keys()):
                        if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
                            review_vocab.add(word)
                    else:
                        review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((1,input_nodes))
        self.layer_1 = np.zeros((1,hidden_nodes))
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review.split(" "):
            self.layer_0[0][self.word2index[word]] = 1

    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def train(self, training_reviews_raw, training_labels):
        
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            ### Forward pass ###

            # Input Layer

            # Hidden layer
            # layer_1 = self.layer_0.dot(self.weights_0_1)
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]
            
            # Output layer
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))

            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            if(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
        
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                            + "% #Correct:" + str(correct) + " #Tested:" + str(i+1) + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        # Input Layer


        # Hidden layer
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# ## Train the network

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.5,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:99.9% Speed(reviews/sec):2281. #Correct:20876 #Trained:24000 Training Accuracy:86.9%

# %% [markdown]
# ## Test the network

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):2791.% #Correct:840 #Tested:1000 Testing Accuracy:84.0%
